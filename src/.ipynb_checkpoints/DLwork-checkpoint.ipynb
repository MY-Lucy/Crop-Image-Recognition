# %%
import torch 
import torchvision
import time
import copy
import matplotlib.pyplot as plt
import numpy as np

# %%
model_name="resnet50" #resnet50模型
feature_extract = True #设置是否使用模型的预训练参数
classify_num = 30 # 分类数量

# %%
train_device = torch.cuda.is_available()

if train_device:
    print("GPU获取成功，train将在gpu上.....")
else:
    print("GPU获取失败，train将CPU上.....")
    
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# GPU获取成功，train将在gpu上.....

# %%
# 冻结不需要训练的层
def set_parameter_requerd_grad(model, feature_extracting):
    if feature_extracting:
        for param in model.parameters():
            param.requires_grad = False

# %%
# model_dl = torchvision.models.resnet50()
# model_dl
# 初始化模型
def initialize_model(is_use_preWeights, classify_num):
    model_dl = torchvision.models.resnet50(weights=torchvision.models.resnet.ResNet50_Weights.IMAGENET1K_V2) #使用预训练参数
    set_parameter_requerd_grad(model_dl, is_use_preWeights) #是否冻结卷积层
    num_in_fea = model_dl.fc.in_features
    model_dl.fc = torch.nn.Sequential(torch.nn.Linear(num_in_fea, classify_num),
                                     torch.nn.LogSoftmax(dim=1))
    return model_dl
# initialize_model(feature_extract, classify_num)

# %%
model_dl = initialize_model(feature_extract, classify_num) # 构造模型
model_save_filename = "model_dl02.pth"
num_epoch = 1000

# 打印出哪些参数需要做训练
print("这些参数需要做训练：")
param_update = []
for name, param in model_dl.named_parameters():
    if param.requires_grad  == True:
        param_update.append(param)
        print("\t",name)
# param_update
# Out:
# 这些参数需要做训练：
# 	 fc.0.weight
# 	 fc.0.bias

# %%
# 设置优化器，学习率，损失函数
optimizer = torch.optim.SGD(param_update,lr= 0.001)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=80, gamma=0.1)
# 动态学习率，测试10轮，每三轮学习率变为原来的0.1
loss_fun = torch.nn.NLLLoss()

# %%
# 定义训练函数
def train(model, dataloader, loss_fun, optim, num_epoch, save_path):
    best_acc = 0 # 记录下最优的那个模型准确率
    model.to(device)# 使用gpu
    
    train_acc_history = []
    train_losses = []
    
    best_model_wts = copy.deepcopy(model.state_dict())
    
    for epoch in range(num_epoch):
        start = time.time() # 计时
        print("一共{}轮，第{}轮".format(num_epoch,epoch + 1))
        print("-"*10)
        
        running_loss = 0.0
        running_corrects = 0
        
        # 开始训练
        model.train() # train模式
         # 遍历数据
        for imgs, targets in dataloader["train"]:
            imgs = imgs.to(device)
            targets = targets.to(device)
            optim.zero_grad()
            outputs = model(imgs)
            loss = loss_fun(outputs, targets)
            loss.backward()
            optim.step()
            preds = outputs.argmax(1)
            running_loss += loss.item() * imgs.size(0)
            running_corrects += torch.sum(preds == targets.data)

        epoch_loss = running_loss / len(dataloader["train"].dataset)
        epoch_acc = running_corrects / len(dataloader["train"].dataset)
        epoch_time = time.time() - start

        if epoch_acc > best_acc:
            best_acc = epoch_acc
            best_model_wts = copy.deepcopy(model.state_dict())
            state = {
                "state_dict" : model.state_dict(),
                "best_acc" : best_acc,
                "optimizer" : optim.state_dict()
            }
            torch.save(state, save_path)
        print("该轮训练结束，用时{}，Loss：{:.2f}，Accuracy:{:.4f},Best_Accracy:{:.4f}"
              .format(epoch_time,epoch_loss,epoch_acc,best_acc))

# %%
# 处理数据
data_dir = "../DataSet/Agricultural-crops/"
batch_size = 32

# %%
def make_data_frame(root_path, batch_size):
    dataset = torchvision.datasets.ImageFolder(root_path, 
                                                 torchvision.transforms.Compose([
                                                     torchvision.transforms.RandomRotation(45), # 旋转
                                                     torchvision.transforms.CenterCrop(224), # 裁剪
                                                     torchvision.transforms.ToTensor(),
                                                     torchvision.transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
                                                 ]))
#     print(len(dataset))
#     print(dataset.classes)
    cat_to_name = dataset.class_to_idx
    valid_percent = int(len(dataset) * 0.2) 
#     train_data : valid_data = 8 : 2
    train_percent = len(dataset) - valid_percent
    train_data, valid_data = torch.utils.data.random_split(dataset, [train_percent, valid_percent])
    dataloader = {index : torch.utils.data.DataLoader(data, batch_size = batch_size, shuffle = True) for index, data in [("train", train_data), ("valid", valid_data)]}
    return dataloader, cat_to_name

# %%
dataloader, cat_to_name = make_data_frame(data_dir, batch_size)
cat_to_name = dict(zip(cat_to_name.values(), cat_to_name.keys()))
print(cat_to_name)
dataloader
# make_data_frame(data_dir, batch_size)
# Out:
# {0: 'Cherry', 1: 'Coffee-plant', 2: 'Cucumber', 3: 'Fox_nut(Makhana)', 4: 'Lemon', 5: 'Olive-tree', 6: 'Pearl_millet(bajra)', 7: 'Tobacco-plant', 8: 'almond', 9: 'banana', 10: 'cardamom', 11: 'chilli', 12: 'clove', 13: 'coconut', 14: 'cotton', 15: 'gram', 16: 'jowar', 17: 'jute', 18: 'maize', 19: 'mustard-oil', 20: 'papaya', 21: 'pineapple', 22: 'rice', 23: 'soyabean', 24: 'sugarcane', 25: 'sunflower', 26: 'tea', 27: 'tomato', 28: 'vigna-radiati(Mung)', 29: 'wheat'}
# {'train': <torch.utils.data.dataloader.DataLoader at 0x196c1845fd0>,
#  'valid': <torch.utils.data.dataloader.DataLoader at 0x196c1845df0>}

# %%
train(model_dl, dataloader, loss_fun, optimizer, num_epoch, model_save_filename)
# Out:
# 一共1000轮，第1轮
# ----------
# 该轮训练结束，用时14.750816583633423，Loss：3.40，Accuracy:0.0361,Best_Accracy:0.0361
# 一共1000轮，第2轮
# ----------
# 该轮训练结束，用时14.415946245193481，Loss：3.40，Accuracy:0.0422,Best_Accracy:0.0422
# 一共1000轮，第3轮
# ----------
# 该轮训练结束，用时14.316194772720337，Loss：3.39，Accuracy:0.0572,Best_Accracy:0.0572
# 一共1000轮，第4轮
# ----------
# 该轮训练结束，用时14.401745080947876，Loss：3.39，Accuracy:0.0467,Best_Accracy:0.0572
# 一共1000轮，第5轮
# ----------
# 该轮训练结束，用时14.347158670425415，Loss：3.37，Accuracy:0.0648,Best_Accracy:0.0648
# 一共1000轮，第6轮
# ----------
# 该轮训练结束，用时14.436996936798096，Loss：3.37，Accuracy:0.0648,Best_Accracy:0.0648
# 一共1000轮，第7轮
# ----------
# 该轮训练结束，用时14.567063808441162，Loss：3.36，Accuracy:0.0768,Best_Accracy:0.0768
# 一共1000轮，第8轮
# ----------
# 该轮训练结束，用时15.123747110366821，Loss：3.35，Accuracy:0.0994,Best_Accracy:0.0994
# 一共1000轮，第9轮
# ----------
# 该轮训练结束，用时15.999028205871582，Loss：3.35，Accuracy:0.0889,Best_Accracy:0.0994
# 一共1000轮，第10轮
# ----------
# 该轮训练结束，用时16.19802165031433，Loss：3.34，Accuracy:0.1190,Best_Accracy:0.1190
# 一共1000轮，第11轮
# ----------
# 该轮训练结束，用时16.426297664642334，Loss：3.33，Accuracy:0.1039,Best_Accracy:0.1190
# 一共1000轮，第12轮
# ----------
# 该轮训练结束，用时16.447776317596436，Loss：3.33，Accuracy:0.1280,Best_Accracy:0.1280
# 一共1000轮，第13轮
# ----------
# 该轮训练结束，用时15.913912773132324，Loss：3.32，Accuracy:0.1401,Best_Accracy:0.1401
# 一共1000轮，第14轮
# ----------
# 该轮训练结束，用时15.827866554260254，Loss：3.31，Accuracy:0.1521,Best_Accracy:0.1521
# 一共1000轮，第15轮
# ----------
# 该轮训练结束，用时15.995148420333862，Loss：3.31，Accuracy:0.1732,Best_Accracy:0.1732
# 一共1000轮，第16轮
# ----------
# 该轮训练结束，用时15.946213722229004，Loss：3.30，Accuracy:0.1777,Best_Accracy:0.1777
# 一共1000轮，第17轮
# ----------
# 该轮训练结束，用时15.946707487106323，Loss：3.29，Accuracy:0.2169,Best_Accracy:0.2169
# 一共1000轮，第18轮
# ----------
# 该轮训练结束，用时16.023967742919922，Loss：3.28，Accuracy:0.2048,Best_Accracy:0.2169
# 一共1000轮，第19轮
# ----------
# 该轮训练结束，用时16.436610221862793，Loss：3.28，Accuracy:0.2123,Best_Accracy:0.2169
# 一共1000轮，第20轮
# ----------
# 该轮训练结束，用时16.243629932403564，Loss：3.27，Accuracy:0.2244,Best_Accracy:0.2244
# 一共1000轮，第21轮
# ----------
# 该轮训练结束，用时16.464349269866943，Loss：3.26，Accuracy:0.2349,Best_Accracy:0.2349
# 一共1000轮，第22轮
# ----------
# 该轮训练结束，用时16.335120677947998，Loss：3.26，Accuracy:0.2319,Best_Accracy:0.2349
# 一共1000轮，第23轮
# ----------
# 该轮训练结束，用时16.308421850204468，Loss：3.25，Accuracy:0.2545,Best_Accracy:0.2545
# 一共1000轮，第24轮
# ----------
# 该轮训练结束，用时16.634745359420776，Loss：3.25，Accuracy:0.2530,Best_Accracy:0.2545
# 一共1000轮，第25轮
# ----------
# 该轮训练结束，用时16.461129903793335，Loss：3.24，Accuracy:0.2756,Best_Accracy:0.2756
# 一共1000轮，第26轮
# ----------
# 该轮训练结束，用时16.62665104866028，Loss：3.23，Accuracy:0.2846,Best_Accracy:0.2846
# 一共1000轮，第27轮
# ----------
# 该轮训练结束，用时17.27948808670044，Loss：3.21，Accuracy:0.3072,Best_Accracy:0.3072
# 一共1000轮，第28轮
# ----------
# 该轮训练结束，用时17.531930685043335，Loss：3.21，Accuracy:0.2877,Best_Accracy:0.3072
# 一共1000轮，第29轮
# ----------
# 该轮训练结束，用时16.9877347946167，Loss：3.21，Accuracy:0.2952,Best_Accracy:0.3072
# 一共1000轮，第30轮
# ----------
# 该轮训练结束，用时16.824827909469604，Loss：3.21，Accuracy:0.3042,Best_Accracy:0.3072
# 一共1000轮，第31轮
# ----------
# 该轮训练结束，用时17.85760807991028，Loss：3.19，Accuracy:0.3178,Best_Accracy:0.3178
# 一共1000轮，第32轮
# ----------
# 该轮训练结束，用时17.07873010635376，Loss：3.19，Accuracy:0.3133,Best_Accracy:0.3178
# 一共1000轮，第33轮
# ----------
# 该轮训练结束，用时16.727632522583008，Loss：3.19，Accuracy:0.3419,Best_Accracy:0.3419
# 一共1000轮，第34轮
# ----------
# 该轮训练结束，用时16.776310920715332，Loss：3.17，Accuracy:0.3584,Best_Accracy:0.3584
# 一共1000轮，第35轮
# ----------
# 该轮训练结束，用时17.30828881263733，Loss：3.16，Accuracy:0.3660,Best_Accracy:0.3660
# 一共1000轮，第36轮
# ----------
# 该轮训练结束，用时17.575685501098633，Loss：3.16，Accuracy:0.3584,Best_Accracy:0.3660
# 一共1000轮，第37轮
# ----------
# 该轮训练结束，用时16.766096353530884，Loss：3.16，Accuracy:0.3675,Best_Accracy:0.3675
# 一共1000轮，第38轮
# ----------
# 该轮训练结束，用时17.0027072429657，Loss：3.15，Accuracy:0.3825,Best_Accracy:0.3825
# 一共1000轮，第39轮
# ----------
# 该轮训练结束，用时16.924245834350586，Loss：3.15，Accuracy:0.3569,Best_Accracy:0.3825
# 一共1000轮，第40轮
# ----------
# 该轮训练结束，用时16.96493935585022，Loss：3.13，Accuracy:0.3765,Best_Accracy:0.3825
# 一共1000轮，第41轮
# ----------
# 该轮训练结束，用时16.647371292114258，Loss：3.13，Accuracy:0.3675,Best_Accracy:0.3825
# 一共1000轮，第42轮
# ----------
# 该轮训练结束，用时16.89108943939209，Loss：3.13，Accuracy:0.3825,Best_Accracy:0.3825
# 一共1000轮，第43轮
# ----------
# 该轮训练结束，用时16.85303044319153，Loss：3.12，Accuracy:0.3630,Best_Accracy:0.3825
# 一共1000轮，第44轮
# ----------
# 该轮训练结束，用时17.113197326660156，Loss：3.11，Accuracy:0.3931,Best_Accracy:0.3931
# 一共1000轮，第45轮
# ----------
# 该轮训练结束，用时16.74604344367981，Loss：3.09，Accuracy:0.3991,Best_Accracy:0.3991
# 一共1000轮，第46轮
# ----------
# 该轮训练结束，用时17.187894344329834，Loss：3.09，Accuracy:0.3855,Best_Accracy:0.3991
# 一共1000轮，第47轮
# ----------
# 该轮训练结束，用时17.05563497543335，Loss：3.08，Accuracy:0.4096,Best_Accracy:0.4096
# 一共1000轮，第48轮
# ----------
# 该轮训练结束，用时17.282878398895264，Loss：3.08，Accuracy:0.4051,Best_Accracy:0.4096
# 一共1000轮，第49轮
# ----------
# 该轮训练结束，用时17.384263038635254，Loss：3.08，Accuracy:0.3961,Best_Accracy:0.4096
# 一共1000轮，第50轮
# ----------
# 该轮训练结束，用时16.95030403137207，Loss：3.07，Accuracy:0.4081,Best_Accracy:0.4096
# 一共1000轮，第51轮
# ----------
# 该轮训练结束，用时16.973092079162598，Loss：3.06，Accuracy:0.4021,Best_Accracy:0.4096
# 一共1000轮，第52轮
# ----------
# 该轮训练结束，用时16.67402219772339，Loss：3.06，Accuracy:0.4127,Best_Accracy:0.4127
# 一共1000轮，第53轮
# ----------
# 该轮训练结束，用时17.21808886528015，Loss：3.04，Accuracy:0.4142,Best_Accracy:0.4142
# 一共1000轮，第54轮
# ----------
# 该轮训练结束，用时16.91761326789856，Loss：3.05，Accuracy:0.4172,Best_Accracy:0.4172
# 一共1000轮，第55轮
# ----------
# 该轮训练结束，用时17.316637992858887，Loss：3.04，Accuracy:0.4187,Best_Accracy:0.4187
# 一共1000轮，第56轮
# ----------
# 该轮训练结束，用时17.076098918914795，Loss：3.03，Accuracy:0.4096,Best_Accracy:0.4187
# 一共1000轮，第57轮
# ----------
# 该轮训练结束，用时16.777886867523193，Loss：3.02，Accuracy:0.4111,Best_Accracy:0.4187
# 一共1000轮，第58轮
# ----------
# 该轮训练结束，用时16.917100429534912，Loss：3.02，Accuracy:0.4081,Best_Accracy:0.4187
# 一共1000轮，第59轮
# ----------
# 该轮训练结束，用时16.81709623336792，Loss：3.01，Accuracy:0.4307,Best_Accracy:0.4307
# 一共1000轮，第60轮
# ----------
# 该轮训练结束，用时17.412205934524536，Loss：3.01，Accuracy:0.4142,Best_Accracy:0.4307
# 一共1000轮，第61轮
# ----------
# 该轮训练结束，用时16.950167417526245，Loss：3.01，Accuracy:0.4262,Best_Accracy:0.4307
# 一共1000轮，第62轮
# ----------
# 该轮训练结束，用时16.850579023361206，Loss：2.99，Accuracy:0.4428,Best_Accracy:0.4428
# 一共1000轮，第63轮
# ----------
# 该轮训练结束，用时16.865350484848022，Loss：2.99，Accuracy:0.4367,Best_Accracy:0.4428
# 一共1000轮，第64轮
# ----------
# 该轮训练结束，用时16.68144130706787，Loss：2.99，Accuracy:0.4232,Best_Accracy:0.4428
# 一共1000轮，第65轮
# ----------
# 该轮训练结束，用时16.84818458557129，Loss：2.98，Accuracy:0.4473,Best_Accracy:0.4473
# 一共1000轮，第66轮
# ----------
# 该轮训练结束，用时17.25022840499878，Loss：2.98，Accuracy:0.4518,Best_Accracy:0.4518
# 一共1000轮，第67轮
# ----------
# 该轮训练结束，用时16.893032789230347，Loss：2.97，Accuracy:0.4518,Best_Accracy:0.4518
# 一共1000轮，第68轮
# ----------
# 该轮训练结束，用时16.55714702606201，Loss：2.96，Accuracy:0.4578,Best_Accracy:0.4578
# 一共1000轮，第69轮
# ----------
# 该轮训练结束，用时17.110995054244995，Loss：2.95，Accuracy:0.4503,Best_Accracy:0.4578
# 一共1000轮，第70轮
# ----------
# 该轮训练结束，用时16.99360156059265，Loss：2.95，Accuracy:0.4880,Best_Accracy:0.4880
# 一共1000轮，第71轮
# ----------
# 该轮训练结束，用时16.687893629074097，Loss：2.94，Accuracy:0.4608,Best_Accracy:0.4880
# 一共1000轮，第72轮
# ----------
# 该轮训练结束，用时16.868052005767822，Loss：2.94，Accuracy:0.4684,Best_Accracy:0.4880
# 一共1000轮，第73轮
# ----------
# 该轮训练结束，用时16.810060262680054，Loss：2.93，Accuracy:0.4563,Best_Accracy:0.4880
# 一共1000轮，第74轮
# ----------
# 该轮训练结束，用时16.88875412940979，Loss：2.92，Accuracy:0.4593,Best_Accracy:0.4880
# 一共1000轮，第75轮
# ----------
# 该轮训练结束，用时16.95978546142578，Loss：2.92，Accuracy:0.4684,Best_Accracy:0.4880
# 一共1000轮，第76轮
# ----------
# 该轮训练结束，用时16.668960094451904，Loss：2.91，Accuracy:0.4578,Best_Accracy:0.4880
# 一共1000轮，第77轮
# ----------
# 该轮训练结束，用时16.727726221084595，Loss：2.91，Accuracy:0.4593,Best_Accracy:0.4880
# 一共1000轮，第78轮
# ----------
# 该轮训练结束，用时16.878568649291992，Loss：2.90，Accuracy:0.4834,Best_Accracy:0.4880
# 一共1000轮，第79轮
# ----------
# 该轮训练结束，用时16.894439935684204，Loss：2.89，Accuracy:0.4729,Best_Accracy:0.4880
# 一共1000轮，第80轮
# ----------
# 该轮训练结束，用时16.778401136398315，Loss：2.89，Accuracy:0.4774,Best_Accracy:0.4880
# 一共1000轮，第81轮
# ----------
# 该轮训练结束，用时16.733794689178467，Loss：2.89，Accuracy:0.4789,Best_Accracy:0.4880
# 一共1000轮，第82轮
# ----------
# 该轮训练结束，用时16.875950574874878，Loss：2.87，Accuracy:0.4699,Best_Accracy:0.4880
# 一共1000轮，第83轮
# ----------
# 该轮训练结束，用时16.697633981704712，Loss：2.87，Accuracy:0.4940,Best_Accracy:0.4940
# 一共1000轮，第84轮
# ----------
# 该轮训练结束，用时17.018884658813477，Loss：2.87，Accuracy:0.4654,Best_Accracy:0.4940
# 一共1000轮，第85轮
# ----------
# 该轮训练结束，用时16.804158687591553，Loss：2.87，Accuracy:0.4669,Best_Accracy:0.4940
# 一共1000轮，第86轮
# ----------
# 该轮训练结束，用时16.975533485412598，Loss：2.86，Accuracy:0.4774,Best_Accracy:0.4940
# 一共1000轮，第87轮
# ----------
# 该轮训练结束，用时16.70940327644348，Loss：2.86，Accuracy:0.4864,Best_Accracy:0.4940
# 一共1000轮，第88轮
# ----------
# 该轮训练结束，用时16.894815921783447，Loss：2.85，Accuracy:0.4819,Best_Accracy:0.4940
# 一共1000轮，第89轮
# ----------
# 该轮训练结束，用时16.81011986732483，Loss：2.84，Accuracy:0.4834,Best_Accracy:0.4940
# 一共1000轮，第90轮
# ----------
# 该轮训练结束，用时17.007508516311646，Loss：2.84，Accuracy:0.4970,Best_Accracy:0.4970
# 一共1000轮，第91轮
# ----------
# 该轮训练结束，用时16.65407133102417，Loss：2.82，Accuracy:0.4774,Best_Accracy:0.4970
# 一共1000轮，第92轮
# ----------
# 该轮训练结束，用时16.870830297470093，Loss：2.82，Accuracy:0.4910,Best_Accracy:0.4970
# 一共1000轮，第93轮
# ----------
# 该轮训练结束，用时16.992995023727417，Loss：2.82，Accuracy:0.5015,Best_Accracy:0.5015
# 一共1000轮，第94轮
# ----------
# 该轮训练结束，用时17.088865518569946，Loss：2.83，Accuracy:0.4925,Best_Accracy:0.5015
# 一共1000轮，第95轮
# ----------
# 该轮训练结束，用时16.602030038833618，Loss：2.81，Accuracy:0.4864,Best_Accracy:0.5015
# 一共1000轮，第96轮
# ----------
# 该轮训练结束，用时16.852754831314087，Loss：2.81，Accuracy:0.4970,Best_Accracy:0.5015
# 一共1000轮，第97轮
# ----------
# 该轮训练结束，用时16.898663997650146，Loss：2.80，Accuracy:0.5090,Best_Accracy:0.5090
# 一共1000轮，第98轮
# ----------
# 该轮训练结束，用时17.048612117767334，Loss：2.78，Accuracy:0.5075,Best_Accracy:0.5090
# 一共1000轮，第99轮
# ----------
# 该轮训练结束，用时16.500839471817017，Loss：2.78，Accuracy:0.4940,Best_Accracy:0.5090
# 一共1000轮，第100轮
# ----------
# 该轮训练结束，用时16.91865038871765，Loss：2.78，Accuracy:0.5015,Best_Accracy:0.5090
# 一共1000轮，第101轮
# ----------
# 该轮训练结束，用时16.78296399116516，Loss：2.78，Accuracy:0.4985,Best_Accracy:0.5090
# 一共1000轮，第102轮
# ----------
# 该轮训练结束，用时16.948527336120605，Loss：2.78，Accuracy:0.5015,Best_Accracy:0.5090
# 一共1000轮，第103轮
# ----------
# 该轮训练结束，用时16.674421548843384，Loss：2.77，Accuracy:0.5166,Best_Accracy:0.5166
# 一共1000轮，第104轮
# ----------
# 该轮训练结束，用时17.470980644226074，Loss：2.77，Accuracy:0.5151,Best_Accracy:0.5166
# 一共1000轮，第105轮
# ----------
# 该轮训练结束，用时17.026564121246338，Loss：2.76，Accuracy:0.5015,Best_Accracy:0.5166
# 一共1000轮，第106轮
# ----------
# 该轮训练结束，用时17.10384225845337，Loss：2.74，Accuracy:0.5211,Best_Accracy:0.5211
# 一共1000轮，第107轮
# ----------
# 该轮训练结束，用时16.88899064064026，Loss：2.74，Accuracy:0.5196,Best_Accracy:0.5211
# 一共1000轮，第108轮
# ----------
# 该轮训练结束，用时17.175634145736694，Loss：2.74，Accuracy:0.5361,Best_Accracy:0.5361
# 一共1000轮，第109轮
# ----------
# 该轮训练结束，用时16.91546320915222，Loss：2.74，Accuracy:0.5060,Best_Accracy:0.5361
# 一共1000轮，第110轮
# ----------
# 该轮训练结束，用时16.79518175125122，Loss：2.70，Accuracy:0.5286,Best_Accracy:0.5361
# 一共1000轮，第111轮
# ----------
# 该轮训练结束，用时17.028066635131836，Loss：2.72，Accuracy:0.5437,Best_Accracy:0.5437
# 一共1000轮，第112轮
# ----------
# 该轮训练结束，用时16.88628339767456，Loss：2.72，Accuracy:0.5271,Best_Accracy:0.5437
# 一共1000轮，第113轮
# ----------
# 该轮训练结束，用时17.172194957733154，Loss：2.72，Accuracy:0.5271,Best_Accracy:0.5437
# 一共1000轮，第114轮
# ----------
# 该轮训练结束，用时17.164591312408447，Loss：2.71，Accuracy:0.5527,Best_Accracy:0.5527
# 一共1000轮，第115轮
# ----------
# 该轮训练结束，用时17.08110237121582，Loss：2.70，Accuracy:0.5407,Best_Accracy:0.5527
# 一共1000轮，第116轮
# ----------
# 该轮训练结束，用时17.059314727783203，Loss：2.70，Accuracy:0.5377,Best_Accracy:0.5527
# 一共1000轮，第117轮
# ----------
# 该轮训练结束，用时16.92013907432556，Loss：2.69，Accuracy:0.5663,Best_Accracy:0.5663
# 一共1000轮，第118轮
# ----------
# 该轮训练结束，用时16.84873056411743，Loss：2.69，Accuracy:0.5527,Best_Accracy:0.5663
# 一共1000轮，第119轮
# ----------
# 该轮训练结束，用时17.023996114730835，Loss：2.67，Accuracy:0.5346,Best_Accracy:0.5663
# 一共1000轮，第120轮
# ----------
# 该轮训练结束，用时17.202114582061768，Loss：2.69，Accuracy:0.5151,Best_Accracy:0.5663
# 一共1000轮，第121轮
# ----------
# 该轮训练结束，用时17.08898377418518，Loss：2.67，Accuracy:0.5452,Best_Accracy:0.5663
# 一共1000轮，第122轮
# ----------
# 该轮训练结束，用时16.55671715736389，Loss：2.67，Accuracy:0.5422,Best_Accracy:0.5663
# 一共1000轮，第123轮
# ----------
# 该轮训练结束，用时16.828941822052002，Loss：2.66，Accuracy:0.5497,Best_Accracy:0.5663
# 一共1000轮，第124轮
# ----------
# 该轮训练结束，用时16.874595642089844，Loss：2.66，Accuracy:0.5527,Best_Accracy:0.5663
# 一共1000轮，第125轮
# ----------
# 该轮训练结束，用时16.968430042266846，Loss：2.64，Accuracy:0.5557,Best_Accracy:0.5663
# 一共1000轮，第126轮
# ----------
# 该轮训练结束，用时16.580320119857788，Loss：2.65，Accuracy:0.5602,Best_Accracy:0.5663
# 一共1000轮，第127轮
# ----------
# 该轮训练结束，用时17.005893230438232，Loss：2.65，Accuracy:0.5437,Best_Accracy:0.5663
# 一共1000轮，第128轮
# ----------
# 该轮训练结束，用时17.09730839729309，Loss：2.64，Accuracy:0.5708,Best_Accracy:0.5708
# 一共1000轮，第129轮
# ----------
# 该轮训练结束，用时16.78012228012085，Loss：2.62，Accuracy:0.5377,Best_Accracy:0.5708
# 一共1000轮，第130轮
# ----------
# 该轮训练结束，用时16.59997272491455，Loss：2.62，Accuracy:0.5572,Best_Accracy:0.5708
# 一共1000轮，第131轮
# ----------
# 该轮训练结束，用时16.878060340881348，Loss：2.64，Accuracy:0.5738,Best_Accracy:0.5738
# 一共1000轮，第132轮
# ----------
# 该轮训练结束，用时16.812191486358643，Loss：2.61，Accuracy:0.5813,Best_Accracy:0.5813
# 一共1000轮，第133轮
# ----------
# 该轮训练结束，用时17.149061918258667，Loss：2.62，Accuracy:0.5602,Best_Accracy:0.5813
# 一共1000轮，第134轮
# ----------
# 该轮训练结束，用时16.62917995452881，Loss：2.59，Accuracy:0.5708,Best_Accracy:0.5813
# 一共1000轮，第135轮
# ----------
# 该轮训练结束，用时17.048357009887695，Loss：2.60，Accuracy:0.5723,Best_Accracy:0.5813
# 一共1000轮，第136轮
# ----------
# 该轮训练结束，用时17.206966400146484，Loss：2.61，Accuracy:0.5557,Best_Accracy:0.5813
# 一共1000轮，第137轮
# ----------
# 该轮训练结束，用时16.78887367248535，Loss：2.60，Accuracy:0.5678,Best_Accracy:0.5813
# 一共1000轮，第138轮
# ----------
# 该轮训练结束，用时16.71233344078064，Loss：2.59，Accuracy:0.5934,Best_Accracy:0.5934
# 一共1000轮，第139轮
# ----------
# 该轮训练结束，用时24.539203882217407，Loss：2.57，Accuracy:0.5843,Best_Accracy:0.5934
# 一共1000轮，第140轮
# ----------
# 该轮训练结束，用时28.464138507843018，Loss：2.59，Accuracy:0.5663,Best_Accracy:0.5934
# 一共1000轮，第141轮
# ----------
# 该轮训练结束，用时24.207776069641113，Loss：2.57，Accuracy:0.5964,Best_Accracy:0.5964
# 一共1000轮，第142轮
# ----------
# 该轮训练结束，用时24.141088485717773，Loss：2.56，Accuracy:0.5889,Best_Accracy:0.5964
# 一共1000轮，第143轮
# ----------
# 该轮训练结束，用时24.159651041030884，Loss：2.57，Accuracy:0.5572,Best_Accracy:0.5964
# 一共1000轮，第144轮
# ----------
# 该轮训练结束，用时23.5427303314209，Loss：2.55，Accuracy:0.5979,Best_Accracy:0.5979
# 一共1000轮，第145轮
# ----------
# 该轮训练结束，用时22.684145212173462，Loss：2.56，Accuracy:0.5919,Best_Accracy:0.5979
# 一共1000轮，第146轮
# ----------
# 该轮训练结束，用时23.199939966201782，Loss：2.54，Accuracy:0.5828,Best_Accracy:0.5979
# 一共1000轮，第147轮
# ----------
# 该轮训练结束，用时23.521041870117188，Loss：2.54，Accuracy:0.5858,Best_Accracy:0.5979
# 一共1000轮，第148轮
# ----------
# 该轮训练结束，用时24.23207426071167，Loss：2.52，Accuracy:0.6039,Best_Accracy:0.6039
# 一共1000轮，第149轮
# ----------
# 该轮训练结束，用时23.251423597335815，Loss：2.53，Accuracy:0.5964,Best_Accracy:0.6039
# 一共1000轮，第150轮
# ----------
# 该轮训练结束，用时22.025520086288452，Loss：2.52，Accuracy:0.6009,Best_Accracy:0.6039
# 一共1000轮，第151轮
# ----------
# 该轮训练结束，用时21.982468366622925，Loss：2.50，Accuracy:0.6084,Best_Accracy:0.6084
# 一共1000轮，第152轮
# ----------
# 该轮训练结束，用时22.11580991744995，Loss：2.53，Accuracy:0.6069,Best_Accracy:0.6084
# 一共1000轮，第153轮
# ----------
# 该轮训练结束，用时21.874659776687622，Loss：2.52，Accuracy:0.6130,Best_Accracy:0.6130
# 一共1000轮，第154轮
# ----------
# 该轮训练结束，用时22.735835552215576，Loss：2.49，Accuracy:0.6009,Best_Accracy:0.6130
# 一共1000轮，第155轮
# ----------
# 该轮训练结束，用时22.11936378479004，Loss：2.53，Accuracy:0.6024,Best_Accracy:0.6130
# 一共1000轮，第156轮
# ----------
# 该轮训练结束，用时22.18776774406433，Loss：2.50，Accuracy:0.5934,Best_Accracy:0.6130
# 一共1000轮，第157轮
# ----------
# 该轮训练结束，用时22.421685218811035，Loss：2.51，Accuracy:0.6130,Best_Accracy:0.6130
# 一共1000轮，第158轮
# ----------
# 该轮训练结束，用时22.08021640777588，Loss：2.47，Accuracy:0.6340,Best_Accracy:0.6340
# 一共1000轮，第159轮
# ----------
# 该轮训练结束，用时21.865458965301514，Loss：2.49，Accuracy:0.6114,Best_Accracy:0.6340
# 一共1000轮，第160轮
# ----------
# 该轮训练结束，用时22.396068811416626，Loss：2.49，Accuracy:0.6084,Best_Accracy:0.6340
# 一共1000轮，第161轮
# ----------
# 该轮训练结束，用时21.7852303981781，Loss：2.49，Accuracy:0.6039,Best_Accracy:0.6340
# 一共1000轮，第162轮
# ----------
# 该轮训练结束，用时22.04084348678589，Loss：2.48，Accuracy:0.6099,Best_Accracy:0.6340
# 一共1000轮，第163轮
# ----------
# 该轮训练结束，用时22.236298322677612，Loss：2.47，Accuracy:0.6114,Best_Accracy:0.6340
# 一共1000轮，第164轮
# ----------
# 该轮训练结束，用时22.060098886489868，Loss：2.46，Accuracy:0.6175,Best_Accracy:0.6340
# 一共1000轮，第165轮
# ----------
# 该轮训练结束，用时22.149707555770874，Loss：2.46，Accuracy:0.6145,Best_Accracy:0.6340
# 一共1000轮，第166轮
# ----------
# 该轮训练结束，用时20.904667854309082，Loss：2.46，Accuracy:0.6145,Best_Accracy:0.6340
# 一共1000轮，第167轮
# ----------
# 该轮训练结束，用时18.20872950553894，Loss：2.43，Accuracy:0.6205,Best_Accracy:0.6340
# 一共1000轮，第168轮
# ----------
# 该轮训练结束，用时20.288198232650757，Loss：2.44，Accuracy:0.6295,Best_Accracy:0.6340
# 一共1000轮，第169轮
# ----------
# 该轮训练结束，用时22.868218898773193，Loss：2.44，Accuracy:0.6280,Best_Accracy:0.6340
# 一共1000轮，第170轮
# ----------
# 该轮训练结束，用时22.713776111602783，Loss：2.45，Accuracy:0.6175,Best_Accracy:0.6340
# 一共1000轮，第171轮
# ----------
# 该轮训练结束，用时22.588499069213867，Loss：2.44，Accuracy:0.6084,Best_Accracy:0.6340
# 一共1000轮，第172轮
# ----------
# 该轮训练结束，用时22.83930540084839，Loss：2.45，Accuracy:0.6265,Best_Accracy:0.6340
# 一共1000轮，第173轮
# ----------
# 该轮训练结束，用时22.26198959350586，Loss：2.44，Accuracy:0.6265,Best_Accracy:0.6340
# 一共1000轮，第174轮
# ----------
# 该轮训练结束，用时21.981327533721924，Loss：2.42，Accuracy:0.6175,Best_Accracy:0.6340
# 一共1000轮，第175轮
# ----------
# 该轮训练结束，用时22.25213074684143，Loss：2.42，Accuracy:0.6340,Best_Accracy:0.6340
# 一共1000轮，第176轮
# ----------
# 该轮训练结束，用时22.66200590133667，Loss：2.42，Accuracy:0.6506,Best_Accracy:0.6506
# 一共1000轮，第177轮
# ----------
# 该轮训练结束，用时23.671550512313843，Loss：2.42，Accuracy:0.6370,Best_Accracy:0.6506
# 一共1000轮，第178轮
# ----------
# 该轮训练结束，用时22.82937502861023，Loss：2.39，Accuracy:0.6370,Best_Accracy:0.6506
# 一共1000轮，第179轮
# ----------
# 该轮训练结束，用时22.74517035484314，Loss：2.40，Accuracy:0.6355,Best_Accracy:0.6506
# 一共1000轮，第180轮
# ----------
# 该轮训练结束，用时21.988901376724243，Loss：2.40，Accuracy:0.6280,Best_Accracy:0.6506
# 一共1000轮，第181轮
# ----------
# 该轮训练结束，用时22.307496786117554，Loss：2.37，Accuracy:0.6521,Best_Accracy:0.6521
# 一共1000轮，第182轮
# ----------
# 该轮训练结束，用时22.273558378219604，Loss：2.38，Accuracy:0.6476,Best_Accracy:0.6521
# 一共1000轮，第183轮
# ----------
# 该轮训练结束，用时21.824430227279663，Loss：2.39，Accuracy:0.6295,Best_Accracy:0.6521
# 一共1000轮，第184轮
# ----------
# 该轮训练结束，用时22.40792202949524，Loss：2.38，Accuracy:0.6370,Best_Accracy:0.6521
# 一共1000轮，第185轮
# ----------
# 该轮训练结束，用时22.445249319076538，Loss：2.38，Accuracy:0.6370,Best_Accracy:0.6521
# 一共1000轮，第186轮
# ----------
# 该轮训练结束，用时22.064064502716064，Loss：2.38，Accuracy:0.6416,Best_Accracy:0.6521
# 一共1000轮，第187轮
# ----------
# 该轮训练结束，用时22.230652809143066，Loss：2.39，Accuracy:0.6280,Best_Accracy:0.6521
# 一共1000轮，第188轮
# ----------
# 该轮训练结束，用时21.827003955841064，Loss：2.37，Accuracy:0.6491,Best_Accracy:0.6521
# 一共1000轮，第189轮
# ----------
# 该轮训练结束，用时22.295352458953857，Loss：2.38，Accuracy:0.6280,Best_Accracy:0.6521
# 一共1000轮，第190轮
# ----------
# 该轮训练结束，用时22.348155736923218，Loss：2.34，Accuracy:0.6446,Best_Accracy:0.6521
# 一共1000轮，第191轮
# ----------
# 该轮训练结束，用时22.066880702972412，Loss：2.36，Accuracy:0.6627,Best_Accracy:0.6627
# 一共1000轮，第192轮
# ----------
# 该轮训练结束，用时22.11939024925232，Loss：2.34，Accuracy:0.6581,Best_Accracy:0.6627
# 一共1000轮，第193轮
# ----------
# 该轮训练结束，用时22.605918407440186，Loss：2.34，Accuracy:0.6596,Best_Accracy:0.6627
# 一共1000轮，第194轮
# ----------
# 该轮训练结束，用时22.14939022064209，Loss：2.33，Accuracy:0.6642,Best_Accracy:0.6642
# 一共1000轮，第195轮
# ----------
# 该轮训练结束，用时21.983478784561157，Loss：2.33，Accuracy:0.6672,Best_Accracy:0.6672
# 一共1000轮，第196轮
# ----------
# 该轮训练结束，用时22.691230535507202，Loss：2.32，Accuracy:0.6611,Best_Accracy:0.6672
# 一共1000轮，第197轮
# ----------
# 该轮训练结束，用时22.228628158569336，Loss：2.32，Accuracy:0.6476,Best_Accracy:0.6672
# 一共1000轮，第198轮
# ----------
# 该轮训练结束，用时22.349607229232788，Loss：2.33，Accuracy:0.6596,Best_Accracy:0.6672
# 一共1000轮，第199轮
# ----------
# 该轮训练结束，用时22.269349813461304，Loss：2.32，Accuracy:0.6476,Best_Accracy:0.6672
# 一共1000轮，第200轮
# ----------
# 该轮训练结束，用时22.344980478286743，Loss：2.33，Accuracy:0.6476,Best_Accracy:0.6672
# 一共1000轮，第201轮
# ----------
# 该轮训练结束，用时22.042731761932373，Loss：2.29，Accuracy:0.6867,Best_Accracy:0.6867
# 一共1000轮，第202轮
# ----------
# 该轮训练结束，用时21.909504175186157，Loss：2.29，Accuracy:0.6491,Best_Accracy:0.6867
# 一共1000轮，第203轮
# ----------
# 该轮训练结束，用时22.190643548965454，Loss：2.30，Accuracy:0.6732,Best_Accracy:0.6867
# 一共1000轮，第204轮
# ----------
# 该轮训练结束，用时22.16809868812561，Loss：2.29，Accuracy:0.6536,Best_Accracy:0.6867
# 一共1000轮，第205轮
# ----------
# 该轮训练结束，用时22.02622938156128，Loss：2.30，Accuracy:0.6732,Best_Accracy:0.6867
# 一共1000轮，第206轮
# ----------
# 该轮训练结束，用时19.765007972717285，Loss：2.29，Accuracy:0.6807,Best_Accracy:0.6867
# 一共1000轮，第207轮
# ----------
# 该轮训练结束，用时20.21155023574829，Loss：2.29，Accuracy:0.6747,Best_Accracy:0.6867
# 一共1000轮，第208轮
# ----------
# 该轮训练结束，用时22.52209186553955，Loss：2.29，Accuracy:0.6521,Best_Accracy:0.6867
# 一共1000轮，第209轮
# ----------
# 该轮训练结束，用时22.275676012039185，Loss：2.30，Accuracy:0.6642,Best_Accracy:0.6867
# 一共1000轮，第210轮
# ----------
# 该轮训练结束，用时22.791128158569336，Loss：2.30，Accuracy:0.6807,Best_Accracy:0.6867
# 一共1000轮，第211轮
# ----------
# 该轮训练结束，用时22.431047201156616，Loss：2.26，Accuracy:0.6596,Best_Accracy:0.6867
# 一共1000轮，第212轮
# ----------
# 该轮训练结束，用时22.51824975013733，Loss：2.26，Accuracy:0.6611,Best_Accracy:0.6867
# 一共1000轮，第213轮
# ----------
# 该轮训练结束，用时22.515496253967285，Loss：2.26，Accuracy:0.6687,Best_Accracy:0.6867
# 一共1000轮，第214轮
# ----------
# 该轮训练结束，用时22.766382694244385，Loss：2.27，Accuracy:0.6807,Best_Accracy:0.6867
# 一共1000轮，第215轮
# ----------
# 该轮训练结束，用时22.696527242660522，Loss：2.25，Accuracy:0.6852,Best_Accracy:0.6867
# 一共1000轮，第216轮
# ----------
# 该轮训练结束，用时22.41022229194641，Loss：2.26，Accuracy:0.6732,Best_Accracy:0.6867
# 一共1000轮，第217轮
# ----------
# 该轮训练结束，用时22.865028142929077，Loss：2.25，Accuracy:0.6747,Best_Accracy:0.6867
# 一共1000轮，第218轮
# ----------
# 该轮训练结束，用时22.250932455062866，Loss：2.24，Accuracy:0.6762,Best_Accracy:0.6867
# 一共1000轮，第219轮
# ----------
# 该轮训练结束，用时22.60081434249878，Loss：2.23，Accuracy:0.6837,Best_Accracy:0.6867
# 一共1000轮，第220轮
# ----------
# 该轮训练结束，用时22.201062440872192，Loss：2.24，Accuracy:0.6717,Best_Accracy:0.6867
# 一共1000轮，第221轮
# ----------
# 该轮训练结束，用时22.568425178527832，Loss：2.23，Accuracy:0.6867,Best_Accracy:0.6867
# 一共1000轮，第222轮
# ----------
# 该轮训练结束，用时22.43812370300293，Loss：2.23，Accuracy:0.6837,Best_Accracy:0.6867
# 一共1000轮，第223轮
# ----------
# 该轮训练结束，用时22.296822547912598，Loss：2.23，Accuracy:0.6747,Best_Accracy:0.6867
# 一共1000轮，第224轮
# ----------
# 该轮训练结束，用时22.762524366378784，Loss：2.21，Accuracy:0.7108,Best_Accracy:0.7108
# 一共1000轮，第225轮
# ----------
# 该轮训练结束，用时20.283803939819336，Loss：2.22，Accuracy:0.6943,Best_Accracy:0.7108
# 一共1000轮，第226轮
# ----------
# 该轮训练结束，用时17.188040256500244，Loss：2.22，Accuracy:0.6988,Best_Accracy:0.7108
# 一共1000轮，第227轮
# ----------
# 该轮训练结束，用时17.294883251190186，Loss：2.21，Accuracy:0.6852,Best_Accracy:0.7108
# 一共1000轮，第228轮
# ----------
# 该轮训练结束，用时17.252655744552612，Loss：2.19，Accuracy:0.6943,Best_Accracy:0.7108
# 一共1000轮，第229轮
# ----------
# 该轮训练结束，用时18.156558990478516，Loss：2.21，Accuracy:0.6762,Best_Accracy:0.7108
# 一共1000轮，第230轮
# ----------
# 该轮训练结束，用时17.172451496124268，Loss：2.19，Accuracy:0.7244,Best_Accracy:0.7244
# 一共1000轮，第231轮
# ----------
# 该轮训练结束，用时18.46339201927185，Loss：2.22，Accuracy:0.6747,Best_Accracy:0.7244
# 一共1000轮，第232轮
# ----------
# 该轮训练结束，用时17.179165363311768，Loss：2.20，Accuracy:0.6807,Best_Accracy:0.7244
# 一共1000轮，第233轮
# ----------
# 该轮训练结束，用时18.371033906936646，Loss：2.20，Accuracy:0.6747,Best_Accracy:0.7244
# 一共1000轮，第234轮
# ----------
# 该轮训练结束，用时18.674729108810425，Loss：2.17，Accuracy:0.6973,Best_Accracy:0.7244
# 一共1000轮，第235轮
# ----------
# 该轮训练结束，用时17.216124296188354，Loss：2.19，Accuracy:0.7048,Best_Accracy:0.7244
# 一共1000轮，第236轮
# ----------
# 该轮训练结束，用时16.9999680519104，Loss：2.17，Accuracy:0.6867,Best_Accracy:0.7244
# 一共1000轮，第237轮
# ----------
# 该轮训练结束，用时17.026538848876953，Loss：2.17，Accuracy:0.6792,Best_Accracy:0.7244
# 一共1000轮，第238轮
# ----------
# 该轮训练结束，用时17.928388833999634，Loss：2.17，Accuracy:0.6988,Best_Accracy:0.7244
# 一共1000轮，第239轮
# ----------
# 该轮训练结束，用时17.11365580558777，Loss：2.16，Accuracy:0.6883,Best_Accracy:0.7244
# 一共1000轮，第240轮
# ----------
# 该轮训练结束，用时17.447188138961792，Loss：2.16，Accuracy:0.6913,Best_Accracy:0.7244
# 一共1000轮，第241轮
# ----------
# 该轮训练结束，用时16.955862283706665，Loss：2.15，Accuracy:0.7123,Best_Accracy:0.7244
# 一共1000轮，第242轮
# ----------
# 该轮训练结束，用时16.8272602558136，Loss：2.15，Accuracy:0.6943,Best_Accracy:0.7244
# 一共1000轮，第243轮
# ----------
# 该轮训练结束，用时17.108506202697754，Loss：2.16，Accuracy:0.7003,Best_Accracy:0.7244
# 一共1000轮，第244轮
# ----------
# 该轮训练结束，用时17.590571880340576，Loss：2.14，Accuracy:0.7033,Best_Accracy:0.7244
# 一共1000轮，第245轮
# ----------
# 该轮训练结束，用时17.22054648399353，Loss：2.14，Accuracy:0.7093,Best_Accracy:0.7244
# 一共1000轮，第246轮
# ----------
# 该轮训练结束，用时16.914793729782104，Loss：2.15，Accuracy:0.7063,Best_Accracy:0.7244
# 一共1000轮，第247轮
# ----------
# 该轮训练结束，用时16.661506414413452，Loss：2.13，Accuracy:0.7093,Best_Accracy:0.7244
# 一共1000轮，第248轮
# ----------
# 该轮训练结束，用时17.261764764785767，Loss：2.13，Accuracy:0.7093,Best_Accracy:0.7244
# 一共1000轮，第249轮
# ----------
# 该轮训练结束，用时16.66410756111145，Loss：2.14，Accuracy:0.7003,Best_Accracy:0.7244
# 一共1000轮，第250轮
# ----------
# 该轮训练结束，用时17.097804069519043，Loss：2.15，Accuracy:0.6973,Best_Accracy:0.7244
# 一共1000轮，第251轮
# ----------
# 该轮训练结束，用时17.037691354751587，Loss：2.14，Accuracy:0.7033,Best_Accracy:0.7244
# 一共1000轮，第252轮
# ----------
# 该轮训练结束，用时17.245589017868042，Loss：2.11，Accuracy:0.7033,Best_Accracy:0.7244
# 一共1000轮，第253轮
# ----------
# 该轮训练结束，用时17.195955276489258，Loss：2.14，Accuracy:0.7063,Best_Accracy:0.7244
# 一共1000轮，第254轮
# ----------
# 该轮训练结束，用时16.879193782806396，Loss：2.10，Accuracy:0.7003,Best_Accracy:0.7244
# 一共1000轮，第255轮
# ----------
# 该轮训练结束，用时17.11767601966858，Loss：2.11，Accuracy:0.7244,Best_Accracy:0.7244
# 一共1000轮，第256轮
# ----------
# 该轮训练结束，用时17.379236698150635，Loss：2.12，Accuracy:0.7003,Best_Accracy:0.7244
# 一共1000轮，第257轮
# ----------
# 该轮训练结束，用时17.33418846130371，Loss：2.11，Accuracy:0.7018,Best_Accracy:0.7244
# 一共1000轮，第258轮
# ----------
# 该轮训练结束，用时17.090620756149292，Loss：2.10，Accuracy:0.7123,Best_Accracy:0.7244
# 一共1000轮，第259轮
# ----------
# 该轮训练结束，用时17.1796875，Loss：2.09，Accuracy:0.7169,Best_Accracy:0.7244
# 一共1000轮，第260轮
# ----------
# 该轮训练结束，用时17.03976345062256，Loss：2.10，Accuracy:0.7003,Best_Accracy:0.7244
# 一共1000轮，第261轮
# ----------
# 该轮训练结束，用时17.079777002334595，Loss：2.10，Accuracy:0.7033,Best_Accracy:0.7244
# 一共1000轮，第262轮
# ----------
# 该轮训练结束，用时17.25406312942505，Loss：2.10，Accuracy:0.7244,Best_Accracy:0.7244
# 一共1000轮，第263轮
# ----------
# 该轮训练结束，用时17.375580310821533，Loss：2.08，Accuracy:0.7123,Best_Accracy:0.7244
# 一共1000轮，第264轮
# ----------
# 该轮训练结束，用时17.482985258102417，Loss：2.08，Accuracy:0.7199,Best_Accracy:0.7244
# 一共1000轮，第265轮
# ----------
# 该轮训练结束，用时16.941603422164917，Loss：2.07，Accuracy:0.7123,Best_Accracy:0.7244
# 一共1000轮，第266轮
# ----------
# 该轮训练结束，用时16.996058702468872，Loss：2.08，Accuracy:0.7304,Best_Accracy:0.7304
# 一共1000轮，第267轮
# ----------
# 该轮训练结束，用时17.114567518234253，Loss：2.07，Accuracy:0.7259,Best_Accracy:0.7304
# 一共1000轮，第268轮
# ----------
# 该轮训练结束，用时16.532643795013428，Loss：2.06，Accuracy:0.7289,Best_Accracy:0.7304
# 一共1000轮，第269轮
# ----------
# 该轮训练结束，用时16.94693112373352，Loss：2.06，Accuracy:0.7108,Best_Accracy:0.7304
# 一共1000轮，第270轮
# ----------
# 该轮训练结束，用时16.646715879440308，Loss：2.07，Accuracy:0.7108,Best_Accracy:0.7304
# 一共1000轮，第271轮
# ----------
# 该轮训练结束，用时17.104008436203003，Loss：2.07，Accuracy:0.7169,Best_Accracy:0.7304
# 一共1000轮，第272轮
# ----------
# 该轮训练结束，用时16.981560230255127，Loss：2.06，Accuracy:0.7410,Best_Accracy:0.7410
# 一共1000轮，第273轮
# ----------
# 该轮训练结束，用时17.328837156295776，Loss：2.03，Accuracy:0.7319,Best_Accracy:0.7410
# 一共1000轮，第274轮
# ----------
# 该轮训练结束，用时17.445528984069824，Loss：2.04，Accuracy:0.7123,Best_Accracy:0.7410
# 一共1000轮，第275轮
# ----------
# 该轮训练结束，用时17.625712633132935，Loss：2.04，Accuracy:0.7319,Best_Accracy:0.7410
# 一共1000轮，第276轮
# ----------
# 该轮训练结束，用时16.958593130111694，Loss：2.07，Accuracy:0.7229,Best_Accracy:0.7410
# 一共1000轮，第277轮
# ----------
# 该轮训练结束，用时17.258965253829956，Loss：2.03，Accuracy:0.7304,Best_Accracy:0.7410
# 一共1000轮，第278轮
# ----------
# 该轮训练结束，用时16.600093364715576，Loss：2.06，Accuracy:0.7003,Best_Accracy:0.7410
# 一共1000轮，第279轮
# ----------
# 该轮训练结束，用时16.927711486816406，Loss：2.04，Accuracy:0.7139,Best_Accracy:0.7410
# 一共1000轮，第280轮
# ----------
# 该轮训练结束，用时16.737601280212402，Loss：2.02，Accuracy:0.7184,Best_Accracy:0.7410
# 一共1000轮，第281轮
# ----------
# 该轮训练结束，用时16.96759581565857，Loss：2.01，Accuracy:0.7380,Best_Accracy:0.7410
# 一共1000轮，第282轮
# ----------
# 该轮训练结束，用时16.645310163497925，Loss：2.02，Accuracy:0.7304,Best_Accracy:0.7410
# 一共1000轮，第283轮
# ----------
# 该轮训练结束，用时17.266958236694336，Loss：2.02，Accuracy:0.7154,Best_Accracy:0.7410
# 一共1000轮，第284轮
# ----------
# 该轮训练结束，用时16.738218069076538，Loss：2.01，Accuracy:0.7410,Best_Accracy:0.7410
# 一共1000轮，第285轮
# ----------
# 该轮训练结束，用时16.642936944961548，Loss：1.98，Accuracy:0.7319,Best_Accracy:0.7410
# 一共1000轮，第286轮
# ----------
# 该轮训练结束，用时16.703104496002197，Loss：2.01，Accuracy:0.7364,Best_Accracy:0.7410
# 一共1000轮，第287轮
# ----------
# 该轮训练结束，用时17.280593156814575，Loss：2.01，Accuracy:0.7319,Best_Accracy:0.7410
# 一共1000轮，第288轮
# ----------
# 该轮训练结束，用时16.975980281829834，Loss：2.00，Accuracy:0.7380,Best_Accracy:0.7410
# 一共1000轮，第289轮
# ----------
# 该轮训练结束，用时16.99734401702881，Loss：1.98，Accuracy:0.7485,Best_Accracy:0.7485
# 一共1000轮，第290轮
# ----------
# 该轮训练结束，用时17.370137691497803，Loss：2.00，Accuracy:0.7304,Best_Accracy:0.7485
# 一共1000轮，第291轮
# ----------
# 该轮训练结束，用时19.578340530395508，Loss：2.01，Accuracy:0.7274,Best_Accracy:0.7485
# 一共1000轮，第292轮
# ----------
# 该轮训练结束，用时20.47717261314392，Loss：1.99，Accuracy:0.7349,Best_Accracy:0.7485
# 一共1000轮，第293轮
# ----------
# 该轮训练结束，用时17.896045923233032，Loss：2.02，Accuracy:0.7078,Best_Accracy:0.7485
# 一共1000轮，第294轮
# ----------
# 该轮训练结束，用时18.143126249313354，Loss：2.00，Accuracy:0.7274,Best_Accracy:0.7485
# 一共1000轮，第295轮
# ----------
# 该轮训练结束，用时17.004648447036743，Loss：1.97，Accuracy:0.7349,Best_Accracy:0.7485
# 一共1000轮，第296轮
# ----------
# 该轮训练结束，用时16.24203848838806，Loss：2.01，Accuracy:0.7274,Best_Accracy:0.7485
# 一共1000轮，第297轮
# ----------
# 该轮训练结束，用时16.86235284805298，Loss：1.99，Accuracy:0.7274,Best_Accracy:0.7485
# 一共1000轮，第298轮
# ----------
# 该轮训练结束，用时16.953964471817017，Loss：1.97，Accuracy:0.7334,Best_Accracy:0.7485
# 一共1000轮，第299轮
# ----------
# 该轮训练结束，用时16.757086277008057，Loss：1.97，Accuracy:0.7380,Best_Accracy:0.7485
# 一共1000轮，第300轮
# ----------
# 该轮训练结束，用时16.858556509017944，Loss：1.97，Accuracy:0.7380,Best_Accracy:0.7485
# 一共1000轮，第301轮
# ----------
# 该轮训练结束，用时16.78273367881775，Loss：2.00，Accuracy:0.7425,Best_Accracy:0.7485
# 一共1000轮，第302轮
# ----------
# 该轮训练结束，用时17.051827669143677，Loss：1.95，Accuracy:0.7485,Best_Accracy:0.7485
# 一共1000轮，第303轮
# ----------
# 该轮训练结束，用时16.961485624313354，Loss：1.98，Accuracy:0.7380,Best_Accracy:0.7485
# 一共1000轮，第304轮
# ----------
# 该轮训练结束，用时17.128907203674316，Loss：1.96，Accuracy:0.7620,Best_Accracy:0.7620
# 一共1000轮，第305轮
# ----------
# 该轮训练结束，用时17.528526544570923，Loss：1.96，Accuracy:0.7545,Best_Accracy:0.7620
# 一共1000轮，第306轮
# ----------
# 该轮训练结束，用时16.92558264732361，Loss：1.97，Accuracy:0.7395,Best_Accracy:0.7620
# 一共1000轮，第307轮
# ----------
# 该轮训练结束，用时16.829604387283325，Loss：1.94，Accuracy:0.7515,Best_Accracy:0.7620
# 一共1000轮，第308轮
# ----------
# 该轮训练结束，用时16.860501527786255，Loss：1.94，Accuracy:0.7500,Best_Accracy:0.7620
# 一共1000轮，第309轮
# ----------
# 该轮训练结束，用时17.05466389656067，Loss：1.92，Accuracy:0.7500,Best_Accracy:0.7620
# 一共1000轮，第310轮
# ----------
# 该轮训练结束，用时16.970529317855835，Loss：1.94，Accuracy:0.7289,Best_Accracy:0.7620
# 一共1000轮，第311轮
# ----------
# 该轮训练结束，用时17.02463150024414，Loss：1.91，Accuracy:0.7560,Best_Accracy:0.7620
# 一共1000轮，第312轮
# ----------
# 该轮训练结束，用时16.65600848197937，Loss：1.91，Accuracy:0.7530,Best_Accracy:0.7620
# 一共1000轮，第313轮
# ----------
# 该轮训练结束，用时17.308234214782715，Loss：1.94，Accuracy:0.7515,Best_Accracy:0.7620
# 一共1000轮，第314轮
# ----------
# 该轮训练结束，用时17.101728439331055，Loss：1.91，Accuracy:0.7380,Best_Accracy:0.7620
# 一共1000轮，第315轮
# ----------
# 该轮训练结束，用时17.14856719970703，Loss：1.92，Accuracy:0.7364,Best_Accracy:0.7620
# 一共1000轮，第316轮
# ----------
# 该轮训练结束，用时17.406588792800903，Loss：1.93，Accuracy:0.7304,Best_Accracy:0.7620
# 一共1000轮，第317轮
# ----------
# 该轮训练结束，用时17.411972284317017，Loss：1.92，Accuracy:0.7485,Best_Accracy:0.7620
# 一共1000轮，第318轮
# ----------
# 该轮训练结束，用时16.830376625061035，Loss：1.92，Accuracy:0.7636,Best_Accracy:0.7636
# 一共1000轮，第319轮
# ----------
# 该轮训练结束，用时17.23592710494995，Loss：1.88，Accuracy:0.7636,Best_Accracy:0.7636
# 一共1000轮，第320轮
# ----------
# 该轮训练结束，用时17.537412881851196，Loss：1.91，Accuracy:0.7515,Best_Accracy:0.7636
# 一共1000轮，第321轮
# ----------
# 该轮训练结束，用时17.202502489089966，Loss：1.93，Accuracy:0.7410,Best_Accracy:0.7636
# 一共1000轮，第322轮
# ----------
# 该轮训练结束，用时16.83574676513672，Loss：1.92，Accuracy:0.7500,Best_Accracy:0.7636
# 一共1000轮，第323轮
# ----------
# 该轮训练结束，用时16.83868718147278，Loss：1.90，Accuracy:0.7560,Best_Accracy:0.7636
# 一共1000轮，第324轮
# ----------
# 该轮训练结束，用时17.343358755111694，Loss：1.94，Accuracy:0.7410,Best_Accracy:0.7636
# 一共1000轮，第325轮
# ----------
# 该轮训练结束，用时18.64105224609375，Loss：1.89，Accuracy:0.7545,Best_Accracy:0.7636
# 一共1000轮，第326轮
# ----------
# 该轮训练结束，用时16.63754177093506，Loss：1.89，Accuracy:0.7500,Best_Accracy:0.7636
# 一共1000轮，第327轮
# ----------
# 该轮训练结束，用时16.76878023147583，Loss：1.87，Accuracy:0.7380,Best_Accracy:0.7636
# 一共1000轮，第328轮
# ----------
# 该轮训练结束，用时17.471168041229248，Loss：1.89，Accuracy:0.7545,Best_Accracy:0.7636
# 一共1000轮，第329轮
# ----------
# 该轮训练结束，用时17.280867099761963，Loss：1.87，Accuracy:0.7530,Best_Accracy:0.7636
# 一共1000轮，第330轮
# ----------
# 该轮训练结束，用时16.987699270248413，Loss：1.90，Accuracy:0.7605,Best_Accracy:0.7636
# 一共1000轮，第331轮
# ----------
# 该轮训练结束，用时17.32387113571167，Loss：1.89，Accuracy:0.7455,Best_Accracy:0.7636
# 一共1000轮，第332轮
# ----------
# 该轮训练结束，用时18.38679265975952，Loss：1.89，Accuracy:0.7545,Best_Accracy:0.7636
# 一共1000轮，第333轮
# ----------
# 该轮训练结束，用时17.395378351211548，Loss：1.88，Accuracy:0.7590,Best_Accracy:0.7636
# 一共1000轮，第334轮
# ----------
# 该轮训练结束，用时17.725345134735107，Loss：1.87，Accuracy:0.7440,Best_Accracy:0.7636
# 一共1000轮，第335轮
# ----------
# 该轮训练结束，用时17.42533779144287，Loss：1.85，Accuracy:0.7545,Best_Accracy:0.7636
# 一共1000轮，第336轮
# ----------
# 该轮训练结束，用时17.817692518234253，Loss：1.88，Accuracy:0.7470,Best_Accracy:0.7636
# 一共1000轮，第337轮
# ----------
# 该轮训练结束，用时16.672590970993042，Loss：1.86，Accuracy:0.7515,Best_Accracy:0.7636
# 一共1000轮，第338轮
# ----------
# 该轮训练结束，用时16.830890417099，Loss：1.86，Accuracy:0.7500,Best_Accracy:0.7636
# 一共1000轮，第339轮
# ----------
# 该轮训练结束，用时17.488513708114624，Loss：1.88，Accuracy:0.7470,Best_Accracy:0.7636
# 一共1000轮，第340轮
# ----------
# 该轮训练结束，用时18.51038932800293，Loss：1.86，Accuracy:0.7560,Best_Accracy:0.7636
# 一共1000轮，第341轮
# ----------
# 该轮训练结束，用时17.974506855010986，Loss：1.86，Accuracy:0.7605,Best_Accracy:0.7636
# 一共1000轮，第342轮
# ----------
# 该轮训练结束，用时16.921119213104248，Loss：1.83，Accuracy:0.7771,Best_Accracy:0.7771
# 一共1000轮，第343轮
# ----------
# 该轮训练结束，用时17.391310214996338，Loss：1.85，Accuracy:0.7620,Best_Accracy:0.7771
# 一共1000轮，第344轮
# ----------
# 该轮训练结束，用时17.196727991104126，Loss：1.85，Accuracy:0.7575,Best_Accracy:0.7771
# 一共1000轮，第345轮
# ----------
# 该轮训练结束，用时16.871910095214844，Loss：1.83，Accuracy:0.7485,Best_Accracy:0.7771
# 一共1000轮，第346轮
# ----------
# 该轮训练结束，用时16.782514810562134，Loss：1.85，Accuracy:0.7605,Best_Accracy:0.7771
# 一共1000轮，第347轮
# ----------
# 该轮训练结束，用时17.28566598892212，Loss：1.85，Accuracy:0.7515,Best_Accracy:0.7771
# 一共1000轮，第348轮
# ----------
# 该轮训练结束，用时17.06754779815674，Loss：1.84，Accuracy:0.7560,Best_Accracy:0.7771
# 一共1000轮，第349轮
# ----------
# 该轮训练结束，用时17.119325160980225，Loss：1.83，Accuracy:0.7636,Best_Accracy:0.7771
# 一共1000轮，第350轮
# ----------
# 该轮训练结束，用时16.98110008239746，Loss：1.82，Accuracy:0.7786,Best_Accracy:0.7786
# 一共1000轮，第351轮
# ----------
# 该轮训练结束，用时17.540024280548096，Loss：1.82，Accuracy:0.7545,Best_Accracy:0.7786
# 一共1000轮，第352轮
# ----------
# 该轮训练结束，用时17.228342056274414，Loss：1.82，Accuracy:0.7560,Best_Accracy:0.7786
# 一共1000轮，第353轮
# ----------
# 该轮训练结束，用时17.121538400650024，Loss：1.81，Accuracy:0.7741,Best_Accracy:0.7786
# 一共1000轮，第354轮
# ----------
# 该轮训练结束，用时17.350850343704224，Loss：1.84，Accuracy:0.7485,Best_Accracy:0.7786
# 一共1000轮，第355轮
# ----------
# 该轮训练结束，用时17.643524885177612，Loss：1.83，Accuracy:0.7741,Best_Accracy:0.7786
# 一共1000轮，第356轮
# ----------
# 该轮训练结束，用时16.92791438102722，Loss：1.83，Accuracy:0.7545,Best_Accracy:0.7786
# 一共1000轮，第357轮
# ----------
# 该轮训练结束，用时17.41632342338562，Loss：1.83，Accuracy:0.7380,Best_Accracy:0.7786
# 一共1000轮，第358轮
# ----------
# 该轮训练结束，用时17.059820890426636，Loss：1.78，Accuracy:0.7801,Best_Accracy:0.7801
# 一共1000轮，第359轮
# ----------
# 该轮训练结束，用时17.82250428199768，Loss：1.83，Accuracy:0.7470,Best_Accracy:0.7801
# 一共1000轮，第360轮
# ----------
# 该轮训练结束，用时18.820480346679688，Loss：1.83，Accuracy:0.7726,Best_Accracy:0.7801
# 一共1000轮，第361轮
# ----------
# 该轮训练结束，用时17.19084620475769，Loss：1.83，Accuracy:0.7500,Best_Accracy:0.7801
# 一共1000轮，第362轮
# ----------
# 该轮训练结束，用时17.127337217330933，Loss：1.77，Accuracy:0.7545,Best_Accracy:0.7801
# 一共1000轮，第363轮
# ----------
# 该轮训练结束，用时16.996484518051147，Loss：1.78，Accuracy:0.7726,Best_Accracy:0.7801
# 一共1000轮，第364轮
# ----------
# 该轮训练结束，用时16.60681676864624，Loss：1.79，Accuracy:0.7666,Best_Accracy:0.7801
# 一共1000轮，第365轮
# ----------
# 该轮训练结束，用时16.639300107955933，Loss：1.78，Accuracy:0.7816,Best_Accracy:0.7816
# 一共1000轮，第366轮
# ----------
# 该轮训练结束，用时17.627583980560303，Loss：1.79，Accuracy:0.7590,Best_Accracy:0.7816
# 一共1000轮，第367轮
# ----------
# 该轮训练结束，用时17.046305179595947，Loss：1.79，Accuracy:0.7696,Best_Accracy:0.7816
# 一共1000轮，第368轮
# ----------
# 该轮训练结束，用时16.773964405059814，Loss：1.80，Accuracy:0.7575,Best_Accracy:0.7816
# 一共1000轮，第369轮
# ----------
# 该轮训练结束，用时17.099833011627197，Loss：1.78，Accuracy:0.7756,Best_Accracy:0.7816
# 一共1000轮，第370轮
# ----------
# 该轮训练结束，用时17.478060007095337，Loss：1.77，Accuracy:0.7666,Best_Accracy:0.7816
# 一共1000轮，第371轮
# ----------
# 该轮训练结束，用时16.786102771759033，Loss：1.78，Accuracy:0.7816,Best_Accracy:0.7816
# 一共1000轮，第372轮
# ----------
# 该轮训练结束，用时17.052025318145752，Loss：1.77，Accuracy:0.7786,Best_Accracy:0.7816
# 一共1000轮，第373轮
# ----------
# 该轮训练结束，用时16.56340742111206，Loss：1.77，Accuracy:0.7756,Best_Accracy:0.7816
# 一共1000轮，第374轮
# ----------
# 该轮训练结束，用时17.414581537246704，Loss：1.77，Accuracy:0.7801,Best_Accracy:0.7816
# 一共1000轮，第375轮
# ----------
# 该轮训练结束，用时16.65315890312195，Loss：1.76，Accuracy:0.7651,Best_Accracy:0.7816
# 一共1000轮，第376轮
# ----------
# 该轮训练结束，用时16.704729795455933，Loss：1.76，Accuracy:0.7711,Best_Accracy:0.7816
# 一共1000轮，第377轮
# ----------
# 该轮训练结束，用时16.776931524276733，Loss：1.76，Accuracy:0.7711,Best_Accracy:0.7816
# 一共1000轮，第378轮
# ----------
# 该轮训练结束，用时17.18795418739319，Loss：1.77，Accuracy:0.7620,Best_Accracy:0.7816
# 一共1000轮，第379轮
# ----------
# 该轮训练结束，用时16.56797456741333，Loss：1.75，Accuracy:0.7907,Best_Accracy:0.7907
# 一共1000轮，第380轮
# ----------
# 该轮训练结束，用时18.43996787071228，Loss：1.72，Accuracy:0.7877,Best_Accracy:0.7907
# 一共1000轮，第381轮
# ----------
# 该轮训练结束，用时18.706403732299805，Loss：1.75，Accuracy:0.7771,Best_Accracy:0.7907
# 一共1000轮，第382轮
# ----------
# 该轮训练结束，用时19.167665004730225，Loss：1.75，Accuracy:0.7801,Best_Accracy:0.7907
# 一共1000轮，第383轮
# ----------
# 该轮训练结束，用时17.611568212509155，Loss：1.74，Accuracy:0.7786,Best_Accracy:0.7907
# 一共1000轮，第384轮
# ----------
# 该轮训练结束，用时17.295795679092407，Loss：1.76，Accuracy:0.7892,Best_Accracy:0.7907
# 一共1000轮，第385轮
# ----------
# 该轮训练结束，用时17.651467084884644，Loss：1.74，Accuracy:0.7696,Best_Accracy:0.7907
# 一共1000轮，第386轮
# ----------
# 该轮训练结束，用时17.477644443511963，Loss：1.73，Accuracy:0.7771,Best_Accracy:0.7907
# 一共1000轮，第387轮
# ----------
# 该轮训练结束，用时17.79801917076111，Loss：1.75，Accuracy:0.7831,Best_Accracy:0.7907
# 一共1000轮，第388轮
# ----------
# 该轮训练结束，用时17.99442982673645，Loss：1.76，Accuracy:0.7636,Best_Accracy:0.7907
# 一共1000轮，第389轮
# ----------
# 该轮训练结束，用时17.40966272354126，Loss：1.73，Accuracy:0.7846,Best_Accracy:0.7907
# 一共1000轮，第390轮
# ----------
# 该轮训练结束，用时17.119631052017212，Loss：1.73，Accuracy:0.7771,Best_Accracy:0.7907
# 一共1000轮，第391轮
# ----------
# 该轮训练结束，用时16.524145364761353，Loss：1.72，Accuracy:0.7786,Best_Accracy:0.7907
# 一共1000轮，第392轮
# ----------
# 该轮训练结束，用时16.733564376831055，Loss：1.72，Accuracy:0.7726,Best_Accracy:0.7907
# 一共1000轮，第393轮
# ----------
# 该轮训练结束，用时17.508628845214844，Loss：1.74，Accuracy:0.7801,Best_Accracy:0.7907
# 一共1000轮，第394轮
# ----------
# 该轮训练结束，用时17.106300115585327，Loss：1.73，Accuracy:0.7786,Best_Accracy:0.7907
# 一共1000轮，第395轮
# ----------
# 该轮训练结束，用时17.676053047180176，Loss：1.71，Accuracy:0.7816,Best_Accracy:0.7907
# 一共1000轮，第396轮
# ----------
# 该轮训练结束，用时17.261982679367065，Loss：1.71，Accuracy:0.7831,Best_Accracy:0.7907
# 一共1000轮，第397轮
# ----------
# 该轮训练结束，用时17.69794535636902，Loss：1.71，Accuracy:0.7922,Best_Accracy:0.7922
# 一共1000轮，第398轮
# ----------
# 该轮训练结束，用时17.29023504257202，Loss：1.72，Accuracy:0.7937,Best_Accracy:0.7937
# 一共1000轮，第399轮
# ----------
# 该轮训练结束，用时17.012696981430054，Loss：1.72，Accuracy:0.7967,Best_Accracy:0.7967
# 一共1000轮，第400轮
# ----------
# 该轮训练结束，用时16.908357858657837，Loss：1.73，Accuracy:0.7846,Best_Accracy:0.7967
# 一共1000轮，第401轮
# ----------
# 该轮训练结束，用时17.24387288093567，Loss：1.68，Accuracy:0.7937,Best_Accracy:0.7967
# 一共1000轮，第402轮
# ----------
# 该轮训练结束，用时16.84188723564148，Loss：1.70，Accuracy:0.7711,Best_Accracy:0.7967
# 一共1000轮，第403轮
# ----------
# 该轮训练结束，用时16.60516333580017，Loss：1.70，Accuracy:0.7696,Best_Accracy:0.7967
# 一共1000轮，第404轮
# ----------
# 该轮训练结束，用时16.845540046691895，Loss：1.70，Accuracy:0.7892,Best_Accracy:0.7967
# 一共1000轮，第405轮
# ----------
# 该轮训练结束，用时16.807353496551514，Loss：1.72，Accuracy:0.7651,Best_Accracy:0.7967
# 一共1000轮，第406轮
# ----------
# 该轮训练结束，用时16.870914459228516，Loss：1.72，Accuracy:0.7771,Best_Accracy:0.7967
# 一共1000轮，第407轮
# ----------
# 该轮训练结束，用时16.736133337020874，Loss：1.67，Accuracy:0.7801,Best_Accracy:0.7967
# 一共1000轮，第408轮
# ----------
# 该轮训练结束，用时17.55616021156311，Loss：1.68，Accuracy:0.7907,Best_Accracy:0.7967
# 一共1000轮，第409轮
# ----------
# 该轮训练结束，用时16.837393522262573，Loss：1.67，Accuracy:0.7786,Best_Accracy:0.7967
# 一共1000轮，第410轮
# ----------
# 该轮训练结束，用时16.93873357772827，Loss：1.71，Accuracy:0.7786,Best_Accracy:0.7967
# 一共1000轮，第411轮
# ----------
# 该轮训练结束，用时16.841542720794678，Loss：1.68，Accuracy:0.7877,Best_Accracy:0.7967
# 一共1000轮，第412轮
# ----------
# 该轮训练结束，用时17.16657304763794，Loss：1.70，Accuracy:0.7861,Best_Accracy:0.7967
# 一共1000轮，第413轮
# ----------
# 该轮训练结束，用时17.539450645446777，Loss：1.66，Accuracy:0.7907,Best_Accracy:0.7967
# 一共1000轮，第414轮
# ----------
# 该轮训练结束，用时16.784549474716187，Loss：1.70，Accuracy:0.7771,Best_Accracy:0.7967
# 一共1000轮，第415轮
# ----------
# 该轮训练结束，用时16.91426181793213，Loss：1.69，Accuracy:0.7771,Best_Accracy:0.7967
# 一共1000轮，第416轮
# ----------
# 该轮训练结束，用时17.369051694869995，Loss：1.67，Accuracy:0.7952,Best_Accracy:0.7967
# 一共1000轮，第417轮
# ----------
# 该轮训练结束，用时16.96748375892639，Loss：1.67，Accuracy:0.7952,Best_Accracy:0.7967
# 一共1000轮，第418轮
# ----------
# 该轮训练结束，用时16.78527069091797，Loss：1.67，Accuracy:0.8057,Best_Accracy:0.8057
# 一共1000轮，第419轮
# ----------
# 该轮训练结束，用时16.644428491592407，Loss：1.69，Accuracy:0.7952,Best_Accracy:0.8057
# 一共1000轮，第420轮
# ----------
# 该轮训练结束，用时18.113553762435913，Loss：1.67，Accuracy:0.7937,Best_Accracy:0.8057
# 一共1000轮，第421轮
# ----------
# 该轮训练结束，用时17.032958030700684，Loss：1.66，Accuracy:0.7892,Best_Accracy:0.8057
# 一共1000轮，第422轮
# ----------
# 该轮训练结束，用时16.970688581466675，Loss：1.66，Accuracy:0.7756,Best_Accracy:0.8057
# 一共1000轮，第423轮
# ----------
# 该轮训练结束，用时17.01260209083557，Loss：1.67，Accuracy:0.7786,Best_Accracy:0.8057
# 一共1000轮，第424轮
# ----------
# 该轮训练结束，用时17.245525121688843，Loss：1.68，Accuracy:0.7831,Best_Accracy:0.8057
# 一共1000轮，第425轮
# ----------
# 该轮训练结束，用时16.962647199630737，Loss：1.66，Accuracy:0.7861,Best_Accracy:0.8057
# 一共1000轮，第426轮
# ----------
# 该轮训练结束，用时16.54532527923584，Loss：1.62，Accuracy:0.8042,Best_Accracy:0.8057
# 一共1000轮，第427轮
# ----------
# 该轮训练结束，用时16.835659503936768，Loss：1.64，Accuracy:0.8027,Best_Accracy:0.8057
# 一共1000轮，第428轮
# ----------
# 该轮训练结束，用时17.56812834739685，Loss：1.67，Accuracy:0.7771,Best_Accracy:0.8057
# 一共1000轮，第429轮
# ----------
# 该轮训练结束，用时16.97396183013916，Loss：1.65，Accuracy:0.7922,Best_Accracy:0.8057
# 一共1000轮，第430轮
# ----------
# 该轮训练结束，用时16.70431661605835，Loss：1.65，Accuracy:0.7877,Best_Accracy:0.8057
# 一共1000轮，第431轮
# ----------
# 该轮训练结束，用时17.07107138633728，Loss：1.64，Accuracy:0.7907,Best_Accracy:0.8057
# 一共1000轮，第432轮
# ----------
# 该轮训练结束，用时17.08353590965271，Loss：1.64，Accuracy:0.7831,Best_Accracy:0.8057
# 一共1000轮，第433轮
# ----------
# 该轮训练结束，用时16.878965616226196，Loss：1.64，Accuracy:0.7922,Best_Accracy:0.8057
# 一共1000轮，第434轮
# ----------
# 该轮训练结束，用时17.03383755683899，Loss：1.62，Accuracy:0.7892,Best_Accracy:0.8057
# 一共1000轮，第435轮
# ----------
# 该轮训练结束，用时17.319993495941162，Loss：1.65，Accuracy:0.7997,Best_Accracy:0.8057
# 一共1000轮，第436轮
# ----------
# 该轮训练结束，用时17.250759601593018，Loss：1.63，Accuracy:0.7846,Best_Accracy:0.8057
# 一共1000轮，第437轮
# ----------
# 该轮训练结束，用时16.81848430633545，Loss：1.60，Accuracy:0.7967,Best_Accracy:0.8057
# 一共1000轮，第438轮
# ----------
# 该轮训练结束，用时16.79513430595398，Loss：1.63，Accuracy:0.8208,Best_Accracy:0.8208
# 一共1000轮，第439轮
# ----------
# 该轮训练结束，用时17.39302110671997，Loss：1.62，Accuracy:0.7801,Best_Accracy:0.8208
# 一共1000轮，第440轮
# ----------
# 该轮训练结束，用时16.76513981819153，Loss：1.62，Accuracy:0.8027,Best_Accracy:0.8208
# 一共1000轮，第441轮
# ----------
# 该轮训练结束，用时16.565951347351074，Loss：1.62，Accuracy:0.7952,Best_Accracy:0.8208
# 一共1000轮，第442轮
# ----------
# 该轮训练结束，用时16.67238211631775，Loss：1.62，Accuracy:0.7922,Best_Accracy:0.8208
# 一共1000轮，第443轮
# ----------
# 该轮训练结束，用时17.26940608024597，Loss：1.63，Accuracy:0.7861,Best_Accracy:0.8208
# 一共1000轮，第444轮
# ----------
# 该轮训练结束，用时17.252996683120728，Loss：1.60，Accuracy:0.8027,Best_Accracy:0.8208
# 一共1000轮，第445轮
# ----------
# 该轮训练结束，用时16.9849534034729，Loss：1.61，Accuracy:0.7937,Best_Accracy:0.8208
# 一共1000轮，第446轮
# ----------
# 该轮训练结束，用时16.918079137802124，Loss：1.63，Accuracy:0.7801,Best_Accracy:0.8208
# 一共1000轮，第447轮
# ----------
# 该轮训练结束，用时17.67392611503601，Loss：1.61，Accuracy:0.7922,Best_Accracy:0.8208
# 一共1000轮，第448轮
# ----------
# 该轮训练结束，用时17.586180448532104，Loss：1.62，Accuracy:0.8072,Best_Accracy:0.8208
# 一共1000轮，第449轮
# ----------
# 该轮训练结束，用时17.03294801712036，Loss：1.62，Accuracy:0.8042,Best_Accracy:0.8208
# 一共1000轮，第450轮
# ----------
# 该轮训练结束，用时16.893346071243286，Loss：1.61，Accuracy:0.7801,Best_Accracy:0.8208
# 一共1000轮，第451轮
# ----------
# 该轮训练结束，用时17.454310417175293，Loss：1.58，Accuracy:0.7967,Best_Accracy:0.8208
# 一共1000轮，第452轮
# ----------
# 该轮训练结束，用时16.894617319107056，Loss：1.60，Accuracy:0.7982,Best_Accracy:0.8208
# 一共1000轮，第453轮
# ----------
# 该轮训练结束，用时17.16068124771118，Loss：1.60，Accuracy:0.8193,Best_Accracy:0.8208
# 一共1000轮，第454轮
# ----------
# 该轮训练结束，用时16.85942554473877，Loss：1.62，Accuracy:0.8027,Best_Accracy:0.8208
# 一共1000轮，第455轮
# ----------
# 该轮训练结束，用时17.322360515594482，Loss：1.58，Accuracy:0.7997,Best_Accracy:0.8208
# 一共1000轮，第456轮
# ----------
# 该轮训练结束，用时16.903048753738403，Loss：1.58，Accuracy:0.8208,Best_Accracy:0.8208
# 一共1000轮，第457轮
# ----------
# 该轮训练结束，用时16.94642996788025，Loss：1.60，Accuracy:0.7937,Best_Accracy:0.8208
# 一共1000轮，第458轮
# ----------
# 该轮训练结束，用时17.566521167755127，Loss：1.58，Accuracy:0.8057,Best_Accracy:0.8208
# 一共1000轮，第459轮
# ----------
# 该轮训练结束，用时17.146955490112305，Loss：1.57，Accuracy:0.8027,Best_Accracy:0.8208
# 一共1000轮，第460轮
# ----------
# 该轮训练结束，用时17.1028892993927，Loss：1.60，Accuracy:0.7952,Best_Accracy:0.8208
# 一共1000轮，第461轮
# ----------
# 该轮训练结束，用时16.85537838935852，Loss：1.56，Accuracy:0.8042,Best_Accracy:0.8208
# 一共1000轮，第462轮
# ----------
# 该轮训练结束，用时17.73477840423584，Loss：1.57，Accuracy:0.7861,Best_Accracy:0.8208
# 一共1000轮，第463轮
# ----------
# 该轮训练结束，用时17.433958292007446，Loss：1.56，Accuracy:0.7907,Best_Accracy:0.8208
# 一共1000轮，第464轮
# ----------
# 该轮训练结束，用时16.941197395324707，Loss：1.58，Accuracy:0.7967,Best_Accracy:0.8208
# 一共1000轮，第465轮
# ----------
# 该轮训练结束，用时17.151854515075684，Loss：1.57，Accuracy:0.7877,Best_Accracy:0.8208
# 一共1000轮，第466轮
# ----------
# 该轮训练结束，用时17.167618989944458，Loss：1.58，Accuracy:0.7982,Best_Accracy:0.8208
# 一共1000轮，第467轮
# ----------
# 该轮训练结束，用时17.35735559463501，Loss：1.58，Accuracy:0.7937,Best_Accracy:0.8208
# 一共1000轮，第468轮
# ----------
# 该轮训练结束，用时17.02381682395935，Loss：1.57，Accuracy:0.7726,Best_Accracy:0.8208
# 一共1000轮，第469轮
# ----------
# 该轮训练结束，用时17.18659996986389，Loss：1.58，Accuracy:0.7892,Best_Accracy:0.8208
# 一共1000轮，第470轮
# ----------
# 该轮训练结束，用时17.542711973190308，Loss：1.57，Accuracy:0.7816,Best_Accracy:0.8208
# 一共1000轮，第471轮
# ----------
# 该轮训练结束，用时17.193116426467896，Loss：1.55，Accuracy:0.7967,Best_Accracy:0.8208
# 一共1000轮，第472轮
# ----------
# 该轮训练结束，用时17.901280879974365，Loss：1.57，Accuracy:0.7982,Best_Accracy:0.8208
# 一共1000轮，第473轮
# ----------
# 该轮训练结束，用时17.525872945785522，Loss：1.54，Accuracy:0.8148,Best_Accracy:0.8208
# 一共1000轮，第474轮
# ----------
# 该轮训练结束，用时17.445355653762817，Loss：1.57，Accuracy:0.8133,Best_Accracy:0.8208
# 一共1000轮，第475轮
# ----------
# 该轮训练结束，用时16.900692462921143，Loss：1.54，Accuracy:0.8072,Best_Accracy:0.8208
# 一共1000轮，第476轮
# ----------
# 该轮训练结束，用时16.84349274635315，Loss：1.56，Accuracy:0.8117,Best_Accracy:0.8208
# 一共1000轮，第477轮
# ----------
# 该轮训练结束，用时17.20145559310913，Loss：1.55，Accuracy:0.8193,Best_Accracy:0.8208
# 一共1000轮，第478轮
# ----------
# 该轮训练结束，用时17.433151483535767，Loss：1.57，Accuracy:0.7786,Best_Accracy:0.8208
# 一共1000轮，第479轮
# ----------
# 该轮训练结束，用时17.015065908432007，Loss：1.55，Accuracy:0.7937,Best_Accracy:0.8208
# 一共1000轮，第480轮
# ----------
# 该轮训练结束，用时17.055370807647705，Loss：1.54，Accuracy:0.8057,Best_Accracy:0.8208
# 一共1000轮，第481轮
# ----------
# 该轮训练结束，用时17.347116947174072，Loss：1.56，Accuracy:0.8042,Best_Accracy:0.8208
# 一共1000轮，第482轮
# ----------
# 该轮训练结束，用时17.02685046195984，Loss：1.56，Accuracy:0.7922,Best_Accracy:0.8208
# 一共1000轮，第483轮
# ----------
# 该轮训练结束，用时17.10880422592163，Loss：1.56，Accuracy:0.7952,Best_Accracy:0.8208
# 一共1000轮，第484轮
# ----------
# 该轮训练结束，用时17.997738122940063，Loss：1.56，Accuracy:0.7952,Best_Accracy:0.8208
# 一共1000轮，第485轮
# ----------
# 该轮训练结束，用时17.675342798233032，Loss：1.53，Accuracy:0.8117,Best_Accracy:0.8208
# 一共1000轮，第486轮
# ----------
# 该轮训练结束，用时17.133580684661865，Loss：1.53，Accuracy:0.7967,Best_Accracy:0.8208
# 一共1000轮，第487轮
# ----------
# 该轮训练结束，用时17.01661229133606，Loss：1.54，Accuracy:0.8117,Best_Accracy:0.8208
# 一共1000轮，第488轮
# ----------
# ...
# 一共1000轮，第839轮
# ----------
# 该轮训练结束，用时17.706714630126953，Loss：1.09，Accuracy:0.8630,Best_Accracy:0.8810
# 一共1000轮，第840轮
# ----------
# 该轮训练结束，用时17.384414196014404，Loss：1.12，Accuracy:0.8494,Best_Accracy:0.8810
# 一共1000轮，第841轮
# ----------
# 该轮训练结束，用时20.88242793083191，Loss：1.12，Accuracy:0.8434,Best_Accracy:0.8810
# 一共1000轮，第842轮
# ----------
# 该轮训练结束，用时18.74564290046692，Loss：1.10，Accuracy:0.8404,Best_Accracy:0.8810
# 一共1000轮，第843轮
# ----------
# 该轮训练结束，用时18.196181297302246，Loss：1.09，Accuracy:0.8645,Best_Accracy:0.8810
# 一共1000轮，第844轮
# ----------
# 该轮训练结束，用时18.95969820022583，Loss：1.08，Accuracy:0.8690,Best_Accracy:0.8810
# 一共1000轮，第845轮
# ----------
# 该轮训练结束，用时17.72614598274231，Loss：1.08，Accuracy:0.8630,Best_Accracy:0.8810
# 一共1000轮，第846轮
# ----------
# 该轮训练结束，用时17.702935457229614，Loss：1.09，Accuracy:0.8419,Best_Accracy:0.8810
# 一共1000轮，第847轮
# ----------
# 该轮训练结束，用时17.361902713775635，Loss：1.13，Accuracy:0.8404,Best_Accracy:0.8810
# 一共1000轮，第848轮
# ----------
# 该轮训练结束，用时17.872107982635498，Loss：1.08，Accuracy:0.8660,Best_Accracy:0.8810
# 一共1000轮，第849轮
# ----------
# 该轮训练结束，用时17.61036491394043，Loss：1.09，Accuracy:0.8795,Best_Accracy:0.8810
# 一共1000轮，第850轮
# ----------
# 该轮训练结束，用时17.476614475250244，Loss：1.11，Accuracy:0.8614,Best_Accracy:0.8810
# 一共1000轮，第851轮
# ----------
# 该轮训练结束，用时17.308282136917114，Loss：1.08，Accuracy:0.8630,Best_Accracy:0.8810
# 一共1000轮，第852轮
# ----------
# 该轮训练结束，用时18.145466804504395，Loss：1.10，Accuracy:0.8569,Best_Accracy:0.8810
# 一共1000轮，第853轮
# ----------
# 该轮训练结束，用时17.360374689102173，Loss：1.09，Accuracy:0.8569,Best_Accracy:0.8810
# 一共1000轮，第854轮
# ----------
# 该轮训练结束，用时17.517311573028564，Loss：1.08，Accuracy:0.8449,Best_Accracy:0.8810
# 一共1000轮，第855轮
# ----------
# 该轮训练结束，用时17.476222038269043，Loss：1.12，Accuracy:0.8419,Best_Accracy:0.8810
# 一共1000轮，第856轮
# ----------
# 该轮训练结束，用时17.739765167236328，Loss：1.10，Accuracy:0.8494,Best_Accracy:0.8810
# 一共1000轮，第857轮
# ----------
# 该轮训练结束，用时17.604878902435303，Loss：1.10，Accuracy:0.8645,Best_Accracy:0.8810
# 一共1000轮，第858轮
# ----------
# 该轮训练结束，用时18.174456357955933，Loss：1.06，Accuracy:0.8825,Best_Accracy:0.8825
# 一共1000轮，第859轮
# ----------
# 该轮训练结束，用时18.19130825996399，Loss：1.06，Accuracy:0.8810,Best_Accracy:0.8825
# 一共1000轮，第860轮
# ----------
# 该轮训练结束，用时17.734760522842407，Loss：1.10，Accuracy:0.8780,Best_Accracy:0.8825
# 一共1000轮，第861轮
# ----------
# 该轮训练结束，用时17.711113691329956，Loss：1.07，Accuracy:0.8690,Best_Accracy:0.8825
# 一共1000轮，第862轮
# ----------
# 该轮训练结束，用时17.54857039451599，Loss：1.07，Accuracy:0.8645,Best_Accracy:0.8825
# 一共1000轮，第863轮
# ----------
# 该轮训练结束，用时18.145842790603638，Loss：1.07，Accuracy:0.8765,Best_Accracy:0.8825
# 一共1000轮，第864轮
# ----------
# 该轮训练结束，用时17.732714653015137，Loss：1.12，Accuracy:0.8735,Best_Accracy:0.8825
# 一共1000轮，第865轮
# ----------
# 该轮训练结束，用时17.73726177215576，Loss：1.07，Accuracy:0.8660,Best_Accracy:0.8825
# 一共1000轮，第866轮
# ----------
# 该轮训练结束，用时17.783395528793335，Loss：1.06，Accuracy:0.8750,Best_Accracy:0.8825
# 一共1000轮，第867轮
# ----------
# 该轮训练结束，用时17.768532514572144，Loss：1.08，Accuracy:0.8599,Best_Accracy:0.8825
# 一共1000轮，第868轮
# ----------
# 该轮训练结束，用时17.592978477478027，Loss：1.08，Accuracy:0.8735,Best_Accracy:0.8825
# 一共1000轮，第869轮
# ----------
# 该轮训练结束，用时17.56145429611206，Loss：1.06，Accuracy:0.8825,Best_Accracy:0.8825
# 一共1000轮，第870轮
# ----------
# 该轮训练结束，用时17.805516958236694，Loss：1.07，Accuracy:0.8720,Best_Accracy:0.8825
# 一共1000轮，第871轮
# ----------
# 该轮训练结束，用时17.528101921081543，Loss：1.06，Accuracy:0.8675,Best_Accracy:0.8825
# 一共1000轮，第872轮
# ----------
# 该轮训练结束，用时17.3878653049469，Loss：1.06，Accuracy:0.8599,Best_Accracy:0.8825
# 一共1000轮，第873轮
# ----------
# 该轮训练结束，用时17.535967350006104，Loss：1.07，Accuracy:0.8645,Best_Accracy:0.8825
# 一共1000轮，第874轮
# ----------
# 该轮训练结束，用时18.247512340545654，Loss：1.07，Accuracy:0.8630,Best_Accracy:0.8825
# 一共1000轮，第875轮
# ----------
# 该轮训练结束，用时17.619712352752686，Loss：1.06，Accuracy:0.8645,Best_Accracy:0.8825
# 一共1000轮，第876轮
# ----------
# 该轮训练结束，用时17.784626722335815，Loss：1.07，Accuracy:0.8494,Best_Accracy:0.8825
# 一共1000轮，第877轮
# ----------
# 该轮训练结束，用时17.677051305770874，Loss：1.05，Accuracy:0.8690,Best_Accracy:0.8825
# 一共1000轮，第878轮
# ----------
# 该轮训练结束，用时17.955848217010498，Loss：1.05，Accuracy:0.8690,Best_Accracy:0.8825
# 一共1000轮，第879轮
# ----------
# 该轮训练结束，用时17.481531381607056，Loss：1.06，Accuracy:0.8705,Best_Accracy:0.8825
# 一共1000轮，第880轮
# ----------
# 该轮训练结束，用时17.49101948738098，Loss：1.04，Accuracy:0.8630,Best_Accracy:0.8825
# 一共1000轮，第881轮
# ----------
# 该轮训练结束，用时17.83827233314514，Loss：1.05，Accuracy:0.8524,Best_Accracy:0.8825
# 一共1000轮，第882轮
# ----------
# 该轮训练结束，用时17.686214685440063，Loss：1.08，Accuracy:0.8479,Best_Accracy:0.8825
# 一共1000轮，第883轮
# ----------
# 该轮训练结束，用时17.582151651382446，Loss：1.07，Accuracy:0.8645,Best_Accracy:0.8825
# 一共1000轮，第884轮
# ----------
# 该轮训练结束，用时17.60426688194275，Loss：1.06，Accuracy:0.8675,Best_Accracy:0.8825
# 一共1000轮，第885轮
# ----------
# 该轮训练结束，用时18.14034652709961，Loss：1.05，Accuracy:0.8539,Best_Accracy:0.8825
# 一共1000轮，第886轮
# ----------
# 该轮训练结束，用时17.698920488357544，Loss：1.06，Accuracy:0.8645,Best_Accracy:0.8825
# 一共1000轮，第887轮
# ----------
# 该轮训练结束，用时17.513959646224976，Loss：1.06，Accuracy:0.8630,Best_Accracy:0.8825
# 一共1000轮，第888轮
# ----------
# 该轮训练结束，用时17.535752534866333，Loss：1.07，Accuracy:0.8675,Best_Accracy:0.8825
# 一共1000轮，第889轮
# ----------
# 该轮训练结束，用时18.050201654434204，Loss：1.07，Accuracy:0.8630,Best_Accracy:0.8825
# 一共1000轮，第890轮
# ----------
# 该轮训练结束，用时18.016910791397095，Loss：1.04，Accuracy:0.8795,Best_Accracy:0.8825
# 一共1000轮，第891轮
# ----------
# 该轮训练结束，用时17.8517906665802，Loss：1.07，Accuracy:0.8630,Best_Accracy:0.8825
# 一共1000轮，第892轮
# ----------
# 该轮训练结束，用时17.696882724761963，Loss：1.06，Accuracy:0.8599,Best_Accracy:0.8825
# 一共1000轮，第893轮
# ----------
# 该轮训练结束，用时18.109261512756348，Loss：1.04，Accuracy:0.8720,Best_Accracy:0.8825
# 一共1000轮，第894轮
# ----------
# 该轮训练结束，用时17.53118062019348，Loss：1.07，Accuracy:0.8645,Best_Accracy:0.8825
# 一共1000轮，第895轮
# ----------
# 该轮训练结束，用时17.813591480255127，Loss：1.07，Accuracy:0.8675,Best_Accracy:0.8825
# 一共1000轮，第896轮
# ----------
# 该轮训练结束，用时18.026704788208008，Loss：1.04，Accuracy:0.8584,Best_Accracy:0.8825
# 一共1000轮，第897轮
# ----------
# 该轮训练结束，用时18.017529249191284，Loss：1.08，Accuracy:0.8554,Best_Accracy:0.8825
# 一共1000轮，第898轮
# ----------
# 该轮训练结束，用时17.59152579307556，Loss：1.03，Accuracy:0.8765,Best_Accracy:0.8825
# 一共1000轮，第899轮
# ----------
# 该轮训练结束，用时17.646072149276733，Loss：1.03，Accuracy:0.8765,Best_Accracy:0.8825
# 一共1000轮，第900轮
# ----------
# 该轮训练结束，用时17.891883373260498，Loss：1.03，Accuracy:0.8479,Best_Accracy:0.8825
# 一共1000轮，第901轮
# ----------
# 该轮训练结束，用时17.755650997161865，Loss：1.04，Accuracy:0.8705,Best_Accracy:0.8825
# 一共1000轮，第902轮
# ----------
# 该轮训练结束，用时17.80813503265381，Loss：1.02，Accuracy:0.8810,Best_Accracy:0.8825
# 一共1000轮，第903轮
# ----------
# 该轮训练结束，用时17.99404287338257，Loss：1.05，Accuracy:0.8720,Best_Accracy:0.8825
# 一共1000轮，第904轮
# ----------
# 该轮训练结束，用时18.25275230407715，Loss：1.07，Accuracy:0.8630,Best_Accracy:0.8825
# 一共1000轮，第905轮
# ----------
# 该轮训练结束，用时17.673671007156372，Loss：1.07，Accuracy:0.8539,Best_Accracy:0.8825
# 一共1000轮，第906轮
# ----------
# 该轮训练结束，用时17.82529377937317，Loss：1.04，Accuracy:0.8614,Best_Accracy:0.8825
# 一共1000轮，第907轮
# ----------
# 该轮训练结束，用时17.899851083755493，Loss：1.09，Accuracy:0.8765,Best_Accracy:0.8825
# 一共1000轮，第908轮
# ----------
# 该轮训练结束，用时18.177475452423096，Loss：1.05，Accuracy:0.8524,Best_Accracy:0.8825
# 一共1000轮，第909轮
# ----------
# 该轮训练结束，用时18.23822832107544，Loss：1.02，Accuracy:0.8825,Best_Accracy:0.8825
# 一共1000轮，第910轮
# ----------
# 该轮训练结束，用时18.93208646774292，Loss：1.05，Accuracy:0.8750,Best_Accracy:0.8825
# 一共1000轮，第911轮
# ----------
# 该轮训练结束，用时17.955954551696777，Loss：1.07，Accuracy:0.8599,Best_Accracy:0.8825
# 一共1000轮，第912轮
# ----------
# 该轮训练结束，用时17.63179063796997，Loss：1.04，Accuracy:0.8750,Best_Accracy:0.8825
# 一共1000轮，第913轮
# ----------
# 该轮训练结束，用时18.346158504486084，Loss：1.02，Accuracy:0.8765,Best_Accracy:0.8825
# 一共1000轮，第914轮
# ----------
# 该轮训练结束，用时17.617713451385498，Loss：1.04，Accuracy:0.8735,Best_Accracy:0.8825
# 一共1000轮，第915轮
# ----------
# 该轮训练结束，用时17.717214107513428，Loss：1.07，Accuracy:0.8660,Best_Accracy:0.8825
# 一共1000轮，第916轮
# ----------
# 该轮训练结束，用时17.146042346954346，Loss：1.04，Accuracy:0.8660,Best_Accracy:0.8825
# 一共1000轮，第917轮
# ----------
# 该轮训练结束，用时16.972660064697266，Loss：1.01，Accuracy:0.8630,Best_Accracy:0.8825
# 一共1000轮，第918轮
# ----------
# 该轮训练结束，用时17.470967292785645，Loss：1.05，Accuracy:0.8765,Best_Accracy:0.8825
# 一共1000轮，第919轮
# ----------
# 该轮训练结束，用时17.449583292007446，Loss：1.05，Accuracy:0.8735,Best_Accracy:0.8825
# 一共1000轮，第920轮
# ----------
# 该轮训练结束，用时17.095677137374878，Loss：1.02，Accuracy:0.8645,Best_Accracy:0.8825
# 一共1000轮，第921轮
# ----------
# 该轮训练结束，用时17.134641885757446，Loss：1.01，Accuracy:0.8524,Best_Accracy:0.8825
# 一共1000轮，第922轮
# ----------
# 该轮训练结束，用时17.559366464614868，Loss：1.04，Accuracy:0.8584,Best_Accracy:0.8825
# 一共1000轮，第923轮
# ----------
# 该轮训练结束，用时17.22192120552063，Loss：1.04，Accuracy:0.8660,Best_Accracy:0.8825
# 一共1000轮，第924轮
# ----------
# 该轮训练结束，用时17.1027512550354，Loss：1.01，Accuracy:0.8825,Best_Accracy:0.8825
# 一共1000轮，第925轮
# ----------
# 该轮训练结束，用时17.072232723236084，Loss：1.04，Accuracy:0.8539,Best_Accracy:0.8825
# 一共1000轮，第926轮
# ----------
# 该轮训练结束，用时17.552631855010986，Loss：1.07，Accuracy:0.8750,Best_Accracy:0.8825
# 一共1000轮，第927轮
# ----------
# 该轮训练结束，用时16.810691833496094，Loss：1.01，Accuracy:0.8675,Best_Accracy:0.8825
# 一共1000轮，第928轮
# ----------
# 该轮训练结束，用时17.019667387008667，Loss：1.04，Accuracy:0.8690,Best_Accracy:0.8825
# 一共1000轮，第929轮
# ----------
# 该轮训练结束，用时17.09217596054077，Loss：1.03，Accuracy:0.8810,Best_Accracy:0.8825
# 一共1000轮，第930轮
# ----------
# 该轮训练结束，用时17.91250705718994，Loss：1.03，Accuracy:0.8645,Best_Accracy:0.8825
# 一共1000轮，第931轮
# ----------
# 该轮训练结束，用时17.01779794692993，Loss：1.05，Accuracy:0.8675,Best_Accracy:0.8825
# 一共1000轮，第932轮
# ----------
# 该轮训练结束，用时17.2940890789032，Loss：1.01，Accuracy:0.8765,Best_Accracy:0.8825
# 一共1000轮，第933轮
# ----------
# 该轮训练结束，用时17.136176109313965，Loss：1.01，Accuracy:0.8795,Best_Accracy:0.8825
# 一共1000轮，第934轮
# ----------
# 该轮训练结束，用时17.309356451034546，Loss：1.01，Accuracy:0.8855,Best_Accracy:0.8855
# 一共1000轮，第935轮
# ----------
# 该轮训练结束，用时17.50356936454773，Loss：1.01，Accuracy:0.8630,Best_Accracy:0.8855
# 一共1000轮，第936轮
# ----------
# 该轮训练结束，用时17.527863264083862，Loss：1.00，Accuracy:0.8660,Best_Accracy:0.8855
# 一共1000轮，第937轮
# ----------
# 该轮训练结束，用时17.724936485290527，Loss：1.01，Accuracy:0.8795,Best_Accracy:0.8855
# 一共1000轮，第938轮
# ----------
# 该轮训练结束，用时17.434052228927612，Loss：1.04，Accuracy:0.8780,Best_Accracy:0.8855
# 一共1000轮，第939轮
# ----------
# 该轮训练结束，用时17.235357761383057，Loss：1.00，Accuracy:0.8780,Best_Accracy:0.8855
# 一共1000轮，第940轮
# ----------
# 该轮训练结束，用时17.206044673919678，Loss：1.01，Accuracy:0.8660,Best_Accracy:0.8855
# 一共1000轮，第941轮
# ----------
# 该轮训练结束，用时17.704588174819946，Loss：1.02，Accuracy:0.8584,Best_Accracy:0.8855
# 一共1000轮，第942轮
# ----------
# 该轮训练结束，用时17.306015968322754，Loss：1.03，Accuracy:0.8720,Best_Accracy:0.8855
# 一共1000轮，第943轮
# ----------
# 该轮训练结束，用时17.110232830047607，Loss：1.02，Accuracy:0.8645,Best_Accracy:0.8855
# 一共1000轮，第944轮
# ----------
# 该轮训练结束，用时17.344952821731567，Loss：1.01，Accuracy:0.8795,Best_Accracy:0.8855
# 一共1000轮，第945轮
# ----------
# 该轮训练结束，用时17.91994857788086，Loss：1.00，Accuracy:0.8810,Best_Accracy:0.8855
# 一共1000轮，第946轮
# ----------
# 该轮训练结束，用时17.0814471244812，Loss：1.01，Accuracy:0.8630,Best_Accracy:0.8855
# 一共1000轮，第947轮
# ----------
# 该轮训练结束，用时17.31718873977661，Loss：1.01，Accuracy:0.8630,Best_Accracy:0.8855
# 一共1000轮，第948轮
# ----------
# 该轮训练结束，用时17.59474205970764，Loss：1.00，Accuracy:0.8720,Best_Accracy:0.8855
# 一共1000轮，第949轮
# ----------
# 该轮训练结束，用时17.65126371383667，Loss：1.03，Accuracy:0.8660,Best_Accracy:0.8855
# 一共1000轮，第950轮
# ----------
# 该轮训练结束，用时17.72397208213806，Loss：1.00，Accuracy:0.8675,Best_Accracy:0.8855
# 一共1000轮，第951轮
# ----------
# 该轮训练结束，用时19.263031244277954，Loss：1.04，Accuracy:0.8765,Best_Accracy:0.8855
# 一共1000轮，第952轮
# ----------
# 该轮训练结束，用时18.974019765853882，Loss：1.06，Accuracy:0.8524,Best_Accracy:0.8855
# 一共1000轮，第953轮
# ----------
# 该轮训练结束，用时19.180156707763672，Loss：1.00，Accuracy:0.8825,Best_Accracy:0.8855
# 一共1000轮，第954轮
# ----------
# 该轮训练结束，用时18.77004361152649，Loss：1.03，Accuracy:0.8690,Best_Accracy:0.8855
# 一共1000轮，第955轮
# ----------
# 该轮训练结束，用时18.726752996444702，Loss：1.03，Accuracy:0.8614,Best_Accracy:0.8855
# 一共1000轮，第956轮
# ----------
# 该轮训练结束，用时18.200897455215454，Loss：1.01，Accuracy:0.8660,Best_Accracy:0.8855
# 一共1000轮，第957轮
# ----------
# 该轮训练结束，用时17.50107741355896，Loss：1.01，Accuracy:0.8660,Best_Accracy:0.8855
# 一共1000轮，第958轮
# ----------
# 该轮训练结束，用时17.840839862823486，Loss：1.01，Accuracy:0.8705,Best_Accracy:0.8855
# 一共1000轮，第959轮
# ----------
# 该轮训练结束，用时17.841803550720215，Loss：1.03，Accuracy:0.8705,Best_Accracy:0.8855
# 一共1000轮，第960轮
# ----------
# 该轮训练结束，用时17.765417098999023，Loss：1.00，Accuracy:0.8599,Best_Accracy:0.8855
# 一共1000轮，第961轮
# ----------
# 该轮训练结束，用时17.56388783454895，Loss：1.02，Accuracy:0.8705,Best_Accracy:0.8855
# 一共1000轮，第962轮
# ----------
# 该轮训练结束，用时17.526416063308716，Loss：1.00，Accuracy:0.8705,Best_Accracy:0.8855
# 一共1000轮，第963轮
# ----------
# 该轮训练结束，用时18.57746124267578，Loss：0.99，Accuracy:0.8825,Best_Accracy:0.8855
# 一共1000轮，第964轮
# ----------
# 该轮训练结束，用时18.49687957763672，Loss：0.99，Accuracy:0.8614,Best_Accracy:0.8855
# 一共1000轮，第965轮
# ----------
# 该轮训练结束，用时18.098427057266235，Loss：1.01，Accuracy:0.8870,Best_Accracy:0.8870
# 一共1000轮，第966轮
# ----------
# 该轮训练结束，用时18.087538719177246，Loss：0.99，Accuracy:0.8780,Best_Accracy:0.8870
# 一共1000轮，第967轮
# ----------
# 该轮训练结束，用时19.175431728363037，Loss：1.00，Accuracy:0.8886,Best_Accracy:0.8886
# 一共1000轮，第968轮
# ----------
# 该轮训练结束，用时19.251054763793945，Loss：1.00，Accuracy:0.8690,Best_Accracy:0.8886
# 一共1000轮，第969轮
# ----------
# 该轮训练结束，用时19.206515550613403，Loss：1.00，Accuracy:0.8720,Best_Accracy:0.8886
# 一共1000轮，第970轮
# ----------
# 该轮训练结束，用时18.8902747631073，Loss：0.99，Accuracy:0.8886,Best_Accracy:0.8886
# 一共1000轮，第971轮
# ----------
# 该轮训练结束，用时19.602535724639893，Loss：1.00，Accuracy:0.8795,Best_Accracy:0.8886
# 一共1000轮，第972轮
# ----------
# 该轮训练结束，用时19.217832565307617，Loss：0.99，Accuracy:0.8750,Best_Accracy:0.8886
# 一共1000轮，第973轮
# ----------
# 该轮训练结束，用时18.653504848480225，Loss：0.98，Accuracy:0.8780,Best_Accracy:0.8886
# 一共1000轮，第974轮
# ----------
# 该轮训练结束，用时19.485628128051758，Loss：0.99，Accuracy:0.8810,Best_Accracy:0.8886
# 一共1000轮，第975轮
# ----------
# 该轮训练结束，用时18.90343737602234，Loss：1.04，Accuracy:0.8554,Best_Accracy:0.8886
# 一共1000轮，第976轮
# ----------
# 该轮训练结束，用时18.37983465194702，Loss：0.98，Accuracy:0.8720,Best_Accracy:0.8886
# 一共1000轮，第977轮
# ----------
# 该轮训练结束，用时26.621599435806274，Loss：1.01，Accuracy:0.8554,Best_Accracy:0.8886
# 一共1000轮，第978轮
# ----------
# 该轮训练结束，用时17.27354645729065，Loss：1.01，Accuracy:0.8720,Best_Accracy:0.8886
# 一共1000轮，第979轮
# ----------
# 该轮训练结束，用时17.502008199691772，Loss：0.98，Accuracy:0.8690,Best_Accracy:0.8886
# 一共1000轮，第980轮
# ----------
# 该轮训练结束，用时17.850160360336304，Loss：0.98，Accuracy:0.8825,Best_Accracy:0.8886
# 一共1000轮，第981轮
# ----------
# 该轮训练结束，用时17.503808736801147，Loss：0.98，Accuracy:0.8675,Best_Accracy:0.8886
# 一共1000轮，第982轮
# ----------
# 该轮训练结束，用时17.05123996734619，Loss：1.01，Accuracy:0.8630,Best_Accracy:0.8886
# 一共1000轮，第983轮
# ----------
# 该轮训练结束，用时17.127557277679443，Loss：0.96，Accuracy:0.8690,Best_Accracy:0.8886
# 一共1000轮，第984轮
# ----------
# 该轮训练结束，用时17.31714653968811，Loss：0.99，Accuracy:0.8690,Best_Accracy:0.8886
# 一共1000轮，第985轮
# ----------
# 该轮训练结束，用时17.042901515960693，Loss：1.00，Accuracy:0.8735,Best_Accracy:0.8886
# 一共1000轮，第986轮
# ----------
# 该轮训练结束，用时17.288898468017578，Loss：0.99，Accuracy:0.8599,Best_Accracy:0.8886
# 一共1000轮，第987轮
# ----------
# 该轮训练结束，用时17.03722643852234，Loss：1.00，Accuracy:0.8645,Best_Accracy:0.8886
# 一共1000轮，第988轮
# ----------
# 该轮训练结束，用时17.517961740493774，Loss：0.98，Accuracy:0.8735,Best_Accracy:0.8886
# 一共1000轮，第989轮
# ----------
# 该轮训练结束，用时17.11091113090515，Loss：0.98，Accuracy:0.8870,Best_Accracy:0.8886
# 一共1000轮，第990轮
# ----------
# 该轮训练结束，用时17.30548334121704，Loss：0.95，Accuracy:0.8810,Best_Accracy:0.8886
# 一共1000轮，第991轮
# ----------
# 该轮训练结束，用时17.28767681121826，Loss：1.01，Accuracy:0.8554,Best_Accracy:0.8886
# 一共1000轮，第992轮
# ----------
# 该轮训练结束，用时18.306161880493164，Loss：0.96，Accuracy:0.8735,Best_Accracy:0.8886
# 一共1000轮，第993轮
# ----------
# 该轮训练结束，用时19.174054622650146，Loss：0.95，Accuracy:0.8795,Best_Accracy:0.8886
# 一共1000轮，第994轮
# ----------
# 该轮训练结束，用时18.111526250839233，Loss：0.98，Accuracy:0.8690,Best_Accracy:0.8886
# 一共1000轮，第995轮
# ----------
# 该轮训练结束，用时19.2268705368042，Loss：0.96，Accuracy:0.8810,Best_Accracy:0.8886
# 一共1000轮，第996轮
# ----------
# 该轮训练结束，用时18.632853984832764，Loss：0.97，Accuracy:0.8750,Best_Accracy:0.8886
# 一共1000轮，第997轮
# ----------
# 该轮训练结束，用时18.498735427856445，Loss：0.98，Accuracy:0.8705,Best_Accracy:0.8886
# 一共1000轮，第998轮
# ----------
# 该轮训练结束，用时17.339448928833008，Loss：0.95，Accuracy:0.8886,Best_Accracy:0.8886
# 一共1000轮，第999轮
# ----------
# 该轮训练结束，用时17.781266927719116，Loss：0.99，Accuracy:0.8795,Best_Accracy:0.8886
# 一共1000轮，第1000轮
# ----------
# 该轮训练结束，用时17.49627661705017，Loss：0.96，Accuracy:0.8690,Best_Accracy:0.8886

# %%
model_dl_test = initialize_model(feature_extract, classify_num)
model_dl_test.to(device)
state = torch.load("./model_dl02.pth")
model_dl_test.load_state_dict(state["state_dict"])
# Out:
# <All keys matched successfully>

# %%
# 测试
valid_data_iter = iter(dataloader['valid'])
imgs, targets = valid_data_iter.next()

if train_device:
    outputs = model_dl_test(imgs.to(device))
else:
    outputs = model_dl_test(imgs)

# %%
# 测试结果可视化
print(outputs.shape) # 结果形状
if train_device:
    preds = outputs.argmax(1).cpu().numpy()
else:
    preds = outputs.argmax(1).numpy()
print(preds)

plt.rcParams["font.sans-serif"]=["simhei"]
plt.rcParams["axes.unicode_minus"]=False
fig = plt.figure(figsize=(20, 20))
col = 4
row = 8
for index in range(col * row):
    ax = fig.add_subplot(row, col, index+1, xticks=[], yticks=[])
    image = imgs[index]
    image = np.array(image).transpose((1,2,0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    image = np.clip(image, 0, 1)
    plt.imshow(image)
    ax.set_title("预测值：{}，实际值：{}".format(cat_to_name[preds[index]], cat_to_name[targets[index].item()]),
                color=("green" if cat_to_name[preds[index]] == cat_to_name[targets[index].item()] else "red"))
# Out:
# torch.Size([32, 30])
# [ 1 18  0 24 14  7 15  0  3 13  4 21 18  2 22  5  2  7 29 17 13 15 24 26
#  23  2 15 27  4  5 10  0]

# %%
preds_right = 0
print("数据集长度：{}".format(len(dataloader["valid"].dataset)))
for imgs, targets in dataloader['valid']:
    imgs = imgs.to(device)
    targets = targets.to(device)
    outputs = model_dl_test(imgs)
    preds = outputs.argmax(1)
    preds_right += torch.sum(preds == targets.data)

print("accuracy:{:.2f}%".format((preds_right.item() / len(dataloader["valid"].dataset) * 100)))
# Out:
# 数据集长度：165
# accuracy:69.70%
